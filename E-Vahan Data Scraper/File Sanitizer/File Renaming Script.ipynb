# %%
pip install pandas openpyxl xlrd
# Out:
# Requirement already satisfied: pandas in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: openpyxl in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (3.1.5)
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: et-xmlfile in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import time
import logging
import warnings
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor
import openpyxl

# Suppress style warnings
warnings.filterwarnings('ignore', category=UserWarning, module='openpyxl.styles.stylesheet')

# Configure logging
logging.basicConfig(
    filename='mass_excel_rename.log',
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

# Hardcoded path - MODIFY WITH YOUR SPECIFIC PATH
ROOT_DIR = r"F:\Flipcarbon\Ajax\Maker"

# Debug mode - set to True for verbose output
DEBUG_MODE = True

def fast_read_title(file_path):
    """Quickly read first cell using openpyxl without loading full file"""
    try:
        wb = openpyxl.load_workbook(file_path, read_only=True, data_only=True)
        sheet = wb.active
        title_value = sheet.cell(row=1, column=1).value
        
        # Handle None values
        if title_value is None:
            return ""
        return str(title_value)
    except Exception as e:
        logging.error(f"Excel read failed: {file_path}: {str(e)}")
        raise RuntimeError(f"Excel read failed: {str(e)}") from e
    finally:
        if 'wb' in locals():
            try:
                wb.close()
            except:
                pass  # Ignore errors on close

def extract_name_from_title(title, filename):
    """Extract just the location code from the title"""
    logging.info(f"Processing title: '{title}'")
    
    # Specific pattern extraction: Get just "Baratang - AN201" from 
    # "Maker Month Wise Data of Baratang - AN201 , Andaman & Nicobar Island (2024)"
    prefix = "Maker Month Wise Data of "
    if "Maker Month Wise Data" in title:
        # Find the start position after "Maker Month Wise Data of "
        # Handle both "Maker Month Wise Data of" and "Maker Month Wise Data  of" (extra space)
        if "Maker Month Wise Data of " in title:
            start = title.find("Maker Month Wise Data of ") + len("Maker Month Wise Data of ")
        else:
            start = title.find("Maker Month Wise Data  of ") + len("Maker Month Wise Data  of ")
        
        # Find the comma after the location code
        end = title.find(",", start)
        if end != -1:
            return title[start:end].strip()
        else:
            # If no comma, try finding the state name in parentheses
            end = title.find(" (", start)
            if end != -1:
                return title[start:end].strip()
            else:
                # If no obvious delimiter, use the rest of the string
                return title[start:].strip()
    
    # Fallback - use original filename
    logging.warning(f"Could not extract name from title: '{title}', using original filename")
    return os.path.splitext(filename)[0]

def process_file(args):
    """Process a single file with enhanced error handling and debugging"""
    folder, filename = args
    file_path = os.path.join(folder, filename)
    original_name, ext = os.path.splitext(filename)
    
    try:
        # Read title from Excel file
        title = fast_read_title(file_path)
        
        if DEBUG_MODE:
            logging.info(f"File: {filename}, Title: '{title}'")
            if not title:
                logging.warning(f"Empty title in file: {filename}")
        
        # Extract just the location code
        new_name = extract_name_from_title(title, filename)
        
        # Clean the new name
        new_name = new_name.replace('/', '-').replace('\\', '-').strip()
        if not new_name:
            raise ValueError("Failed to extract a valid name")
            
        new_filename = f"{new_name}{ext}"
        new_path = os.path.join(folder, new_filename)
        
        if DEBUG_MODE:
            logging.info(f"Extracted name: '{new_name}' for file: {filename}")
        
        # Skip if no change needed
        if new_filename == filename:
            return (folder, "skipped (same name)")
            
        if os.path.exists(new_path):
            # Add timestamp to make unique
            timestamp = datetime.now().strftime("%Y%m%d%H%M%S")
            new_filename = f"{new_name}_{timestamp}{ext}"
            new_path = os.path.join(folder, new_filename)
            logging.warning(f"Duplicate name, adding timestamp: {new_filename}")
            
        # Perform the rename
        os.rename(file_path, new_path)
        return (folder, "success")

    except Exception as e:
        error_msg = f"{file_path} - {str(e)}"
        logging.error(error_msg)
        print(f"Error: {error_msg}") if DEBUG_MODE else None
        return (folder, "error")

def process_folder(max_workers=4):
    """Process files in parallel with thread pool"""
    folder_stats = {}
    
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Collect all files first for accurate progress
        file_count = 0
        all_files = []
        for folder, _, files in os.walk(ROOT_DIR):
            excel_files = [f for f in files if f.lower().endswith(('.xlsx', '.xls'))]
            all_files.extend([(folder, f) for f in excel_files])
            folder_stats[folder] = {
                'total': len(excel_files),
                'success': 0,
                'error': 0,
                'skipped': 0
            }
        file_count = len(all_files)
        
        # Process files with progress updates
        start_time = time.time()
        processed = 0
        print(f"\nProcessing {file_count} files across {len(folder_stats)} folders...")
        
        # For debugging, process just a few files first
        if DEBUG_MODE:
            test_files = all_files[:5] if len(all_files) > 5 else all_files
            print(f"DEBUG MODE: Processing {len(test_files)} sample files first...")
            
            for file_args in test_files:
                folder, filename = file_args
                print(f"Processing: {os.path.join(folder, filename)}")
                result = process_file(file_args)
                print(f"Result: {result[1]}")
            
            proceed = input("Continue with all files? (y/n): ").lower() == 'y'
            if not proceed:
                print("Operation cancelled by user")
                return folder_stats
        
        # Process all files
        for result in executor.map(process_file, all_files):
            folder, status = result
            status_key = status.split()[0]  # Get first word (success, error, skipped)
            folder_stats[folder][status_key] += 1
            processed += 1
            
            # Progress update every 50 files or 5 seconds
            if processed % 50 == 0 or (time.time() - start_time) > 5:
                elapsed = time.time() - start_time
                print(f"Processed {processed}/{file_count} files ({elapsed:.1f}s)")
                start_time = time.time()  # Reset timer

    return folder_stats

def print_stats(folder_stats):
    """Print detailed statistics table"""
    print("\n\nProcessing Summary:")
    print("-" * 85)
    print(f"{'Folder Path':<50} | {'Total':>6} | {'Success':>7} | {'Errors':>6} | {'Skipped':>7}")
    print("-" * 85)
    
    for folder, stats in sorted(folder_stats.items()):
        print(f"{folder:<50} | {stats['total']:>6} | {stats['success']:>7} | "
              f"{stats['error']:>6} | {stats['skipped']:>7}")
    
    totals = {
        'total': sum(s['total'] for s in folder_stats.values()),
        'success': sum(s['success'] for s in folder_stats.values()),
        'error': sum(s['error'] for s in folder_stats.values()),
        'skipped': sum(s['skipped'] for s in folder_stats.values())
    }
    
    print("-" * 85)
    print(f"{'TOTALS':<50} | {totals['total']:>6} | {totals['success']:>7} | "
          f"{totals['error']:>6} | {totals['skipped']:>7}")
    print("-" * 85)

def analyze_sample_files():
    """Analyze a few sample files to debug title extraction issues"""
    print("\nSample File Analysis:")
    print("-" * 100)
    
    for folder, _, files in os.walk(ROOT_DIR):
        excel_files = [f for f in files if f.lower().endswith(('.xlsx', '.xls'))]
        if not excel_files:
            continue
            
        # Take up to 2 files from each folder for analysis
        sample_files = excel_files[:2]
        for filename in sample_files:
            file_path = os.path.join(folder, filename)
            try:
                title = fast_read_title(file_path)
                new_name = extract_name_from_title(title, filename)
                
                print(f"File: {filename}")
                print(f"  Path: {folder}")
                print(f"  Title in A1: '{title}'")
                print(f"  Extracted Name: '{new_name}'")
                print("-" * 100)
                
            except Exception as e:
                print(f"File: {filename}")
                print(f"  Path: {folder}")
                print(f"  ERROR: {str(e)}")
                print("-" * 100)

if __name__ == "__main__":
    # Validate path before processing
    if not os.path.isdir(ROOT_DIR):
        print(f"Error: Path does not exist or is not a directory\n{ROOT_DIR}")
        exit(1)
    
    print(f"Starting processing for:\n{ROOT_DIR}")
    
    # First analyze sample files if in debug mode
    if DEBUG_MODE:
        choice = input("Run sample analysis first? (y/n): ").lower()
        if choice == 'y':
            analyze_sample_files()
    
    # Start the main processing
    start = time.time()
    stats = process_folder()
    duration = time.time() - start
    
    print_stats(stats)
    print(f"\nTotal processing time: {duration:.2f} seconds")
    print(f"Log file: mass_excel_rename.log")
# Out:
# Starting processing for:
# F:\Flipcarbon\Ajax\Maker
#
# Sample File Analysis:
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of Baratang - AN201.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island
#   Title in A1: 'Maker Month Wise Data  of Baratang - AN201 , Andaman & Nicobar Island (2024)'
#   Extracted Name: 'Baratang - AN201'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of Car Nicobar - AN211.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island
#   Title in A1: 'Maker Month Wise Data  of Car Nicobar - AN211 , Andaman & Nicobar Island (2024)'
#   Extracted Name: 'Car Nicobar - AN211'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of Adoni RTO - AP221.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Andhra Pradesh
#   Title in A1: 'Maker Month Wise Data  of Adoni RTO - AP221 , Andhra Pradesh (2024)'
#   Extracted Name: 'Adoni RTO - AP221'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of Amalapuram RTA - AP205.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Andhra Pradesh
#   Title in A1: 'Maker Month Wise Data  of Amalapuram RTA - AP205 , Andhra Pradesh (2024)'
#   Extracted Name: 'Amalapuram RTA - AP205'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of ANJAW - AR17.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Arunachal Pradesh
#   Title in A1: 'Maker Month Wise Data  of ANJAW - AR17 , Arunachal Pradesh (2024)'
#   Extracted Name: 'ANJAW - AR17'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of CHANGLANG - AR12.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Arunachal Pradesh
#   Title in A1: 'Maker Month Wise Data  of CHANGLANG - AR12 , Arunachal Pradesh (2024)'
#   Extracted Name: 'CHANGLANG - AR12'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of BARPETA - AS15.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Assam
#   Title in A1: 'Maker Month Wise Data  of BARPETA - AS15 , Assam (2024)'
#   Extracted Name: 'BARPETA - AS15'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of BISWANATH CHARIALI - AS32.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Assam
#   Title in A1: 'Maker Month Wise Data  of BISWANATH CHARIALI - AS32 , Assam (2024)'
#   Extracted Name: 'BISWANATH CHARIALI - AS32'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of ARARIA - BR38.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Bihar
#   Title in A1: 'Maker Month Wise Data  of ARARIA - BR38 , Bihar (2024)'
#   Extracted Name: 'ARARIA - BR38'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of AURANGABAD - BR26.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Bihar
#   Title in A1: 'Maker Month Wise Data  of AURANGABAD - BR26 , Bihar (2024)'
#   Extracted Name: 'AURANGABAD - BR26'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of CHANDIGARH UT (RLA AND STA) - CH1.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Chandigarh
#   Title in A1: 'Maker Month Wise Data  of CHANDIGARH UT (RLA AND STA) - CH1 , Chandigarh (2024)'
#   Extracted Name: 'CHANDIGARH UT (RLA AND STA) - CH1'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of Ambikapur RTO - CG15.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Chhattisgarh
#   Title in A1: 'Maker Month Wise Data  of Ambikapur RTO - CG15 , Chhattisgarh (2024)'
#   Extracted Name: 'Ambikapur RTO - CG15'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of Balod DTO - CG24.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Chhattisgarh
#   Title in A1: 'Maker Month Wise Data  of Balod DTO - CG24 , Chhattisgarh (2024)'
#   Extracted Name: 'Balod DTO - CG24'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of BURARI AUTO UNIT - DL53.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Delhi
#   Title in A1: 'Maker Month Wise Data  of BURARI AUTO UNIT - DL53 , Delhi (2024)'
#   Extracted Name: 'BURARI AUTO UNIT - DL53'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of BURARI TAXI UNIT - DL52.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Delhi
#   Title in A1: 'Maker Month Wise Data  of BURARI TAXI UNIT - DL52 , Delhi (2024)'
#   Extracted Name: 'BURARI TAXI UNIT - DL52'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of ASSISTANT DIRECTOR OF TRANSPORT ENF. (NORTH) PANAJI - GA107.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Goa
#   Title in A1: 'Maker Month Wise Data  of ASSISTANT DIRECTOR OF TRANSPORT ENF. (NORTH) PANAJI - GA107 , Goa (2024)'
#   Extracted Name: 'ASSISTANT DIRECTOR OF TRANSPORT ENF. (NORTH) PANAJI - GA107'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of BICHOLIM RTO - GA4.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Goa
#   Title in A1: 'Maker Month Wise Data  of BICHOLIM RTO - GA4 , Goa (2024)'
#   Extracted Name: 'BICHOLIM RTO - GA4'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of AAHWA - GJ30.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Gujarat
#   Title in A1: 'Maker Month Wise Data  of AAHWA - GJ30 , Gujarat (2024)'
#   Extracted Name: 'AAHWA - GJ30'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of Ahmedabad (Rural).xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Gujarat
#   Title in A1: 'Maker Month Wise Data  of Ahmedabad (Rural), Bawla ARTO - GJ38 , Gujarat (2024)'
#   Extracted Name: 'Ahmedabad (Rural)'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of AMBALA CITY - HR1.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Haryana
#   Title in A1: 'Maker Month Wise Data  of AMBALA CITY - HR1 , Haryana (2024)'
#   Extracted Name: 'AMBALA CITY - HR1'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of BAHADURGARH - HR13.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Haryana
#   Title in A1: 'Maker Month Wise Data  of BAHADURGARH - HR13 , Haryana (2024)'
#   Extracted Name: 'BAHADURGARH - HR13'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of HRTC BAIJNATH - HP113.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Himachal Pradesh
#   Title in A1: 'Maker Month Wise Data  of HRTC BAIJNATH - HP113 , Himachal Pradesh (2024)'
#   Extracted Name: 'HRTC BAIJNATH - HP113'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of HRTC CHAMBA - HP115.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Himachal Pradesh
#   Title in A1: 'Maker Month Wise Data  of HRTC CHAMBA - HP115 , Himachal Pradesh (2024)'
#   Extracted Name: 'HRTC CHAMBA - HP115'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of ANANTNAG ARTO - JK3.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Jammu and Kashmir
#   Title in A1: 'Maker Month Wise Data  of ANANTNAG ARTO - JK3 , Jammu and Kashmir (2024)'
#   Extracted Name: 'ANANTNAG ARTO - JK3'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of DODA ARTO - JK6.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Jammu and Kashmir
#   Title in A1: 'Maker Month Wise Data  of DODA ARTO - JK6 , Jammu and Kashmir (2024)'
#   Extracted Name: 'DODA ARTO - JK6'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of Authorised Testing  Centre (TUV SUD).xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Jharkhand
#   Title in A1: 'Maker Month Wise Data  of Authorised Testing  Centre (TUV SUD), Ranchi - JH201 , Jharkhand (2024)'
#   Extracted Name: 'Authorised Testing  Centre (TUV SUD)'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of BOKARO - JH9.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Jharkhand
#   Title in A1: 'Maker Month Wise Data  of BOKARO - JH9 , Jharkhand (2024)'
#   Extracted Name: 'BOKARO - JH9'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of ATHANI ARTO - KA71.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Karnataka
#   Title in A1: 'Maker Month Wise Data  of ATHANI ARTO - KA71 , Karnataka (2024)'
#   Extracted Name: 'ATHANI ARTO - KA71'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of BAILHONGAL  RTO - KA24.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Karnataka
#   Title in A1: 'Maker Month Wise Data  of BAILHONGAL  RTO - KA24 , Karnataka (2024)'
#   Extracted Name: 'BAILHONGAL  RTO - KA24'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of ADOOR SRTO - KL26.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Kerala
#   Title in A1: 'Maker Month Wise Data  of ADOOR SRTO - KL26 , Kerala (2024)'
#   Extracted Name: 'ADOOR SRTO - KL26'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of ALATHUR SRTO - KL49.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Kerala
#   Title in A1: 'Maker Month Wise Data  of ALATHUR SRTO - KL49 , Kerala (2024)'
#   Extracted Name: 'ALATHUR SRTO - KL49'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of KARGIL ARTO - LA1.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Ladakh
#   Title in A1: 'Maker Month Wise Data  of KARGIL ARTO - LA1 , Ladakh (2024)'
#   Extracted Name: 'KARGIL ARTO - LA1'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of AMINI - LD3.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Lakshadweep
#   Title in A1: 'Maker Month Wise Data  of AMINI - LD3 , Lakshadweep (2024)'
#   Extracted Name: 'AMINI - LD3'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of KAVARATTI - LD1.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Lakshadweep
#   Title in A1: 'Maker Month Wise Data  of KAVARATTI - LD1 , Lakshadweep (2024)'
#   Extracted Name: 'KAVARATTI - LD1'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of AGAR MALWA RTO - MP70.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Madhya Pradesh
#   Title in A1: 'Maker Month Wise Data  of AGAR MALWA RTO - MP70 , Madhya Pradesh (2024)'
#   Extracted Name: 'AGAR MALWA RTO - MP70'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of ASHOKNAGAR DTO - MP67.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Madhya Pradesh
#   Title in A1: 'Maker Month Wise Data  of ASHOKNAGAR DTO - MP67 , Madhya Pradesh (2024)'
#   Extracted Name: 'ASHOKNAGAR DTO - MP67'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of AKLUJ - MH45.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Maharashtra
#   Title in A1: 'Maker Month Wise Data  of AKLUJ - MH45 , Maharashtra (2024)'
#   Extracted Name: 'AKLUJ - MH45'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of AMRAWATI - MH27.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Maharashtra
#   Title in A1: 'Maker Month Wise Data  of AMRAWATI - MH27 , Maharashtra (2024)'
#   Extracted Name: 'AMRAWATI - MH27'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of BISHNUPUR - MN5.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Manipur
#   Title in A1: 'Maker Month Wise Data  of BISHNUPUR - MN5 , Manipur (2024)'
#   Extracted Name: 'BISHNUPUR - MN5'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of CHURACHANDPUR - MN2.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Manipur
#   Title in A1: 'Maker Month Wise Data  of CHURACHANDPUR - MN2 , Manipur (2024)'
#   Extracted Name: 'CHURACHANDPUR - MN2'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of AMPATI - ML14.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Meghalaya
#   Title in A1: 'Maker Month Wise Data  of AMPATI - ML14 , Meghalaya (2024)'
#   Extracted Name: 'AMPATI - ML14'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of KHLIEHRIAT - ML11.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Meghalaya
#   Title in A1: 'Maker Month Wise Data  of KHLIEHRIAT - ML11 , Meghalaya (2024)'
#   Extracted Name: 'KHLIEHRIAT - ML11'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of AIZAWL DTO - MZ1.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Mizoram
#   Title in A1: 'Maker Month Wise Data  of AIZAWL DTO - MZ1 , Mizoram (2024)'
#   Extracted Name: 'AIZAWL DTO - MZ1'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of CHAMPHAI - MZ4.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Mizoram
#   Title in A1: 'Maker Month Wise Data  of CHAMPHAI - MZ4 , Mizoram (2024)'
#   Extracted Name: 'CHAMPHAI - MZ4'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of DIMAPUR DTO - NL7.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Nagaland
#   Title in A1: 'Maker Month Wise Data  of DIMAPUR DTO - NL7 , Nagaland (2024)'
#   Extracted Name: 'DIMAPUR DTO - NL7'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of MON DTO - NL4.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Nagaland
#   Title in A1: 'Maker Month Wise Data  of MON DTO - NL4 , Nagaland (2024)'
#   Extracted Name: 'MON DTO - NL4'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of ANGUL RTO - OD19.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Odisha
#   Title in A1: 'Maker Month Wise Data  of ANGUL RTO - OD19 , Odisha (2024)'
#   Extracted Name: 'ANGUL RTO - OD19'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of BALASORE RTO - OD1.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Odisha
#   Title in A1: 'Maker Month Wise Data  of BALASORE RTO - OD1 , Odisha (2024)'
#   Extracted Name: 'BALASORE RTO - OD1'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of BAHOUR - PY11.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Puducherry
#   Title in A1: 'Maker Month Wise Data  of BAHOUR - PY11 , Puducherry (2024)'
#   Extracted Name: 'BAHOUR - PY11'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of KARAIKAL - PY2.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Puducherry
#   Title in A1: 'Maker Month Wise Data  of KARAIKAL - PY2 , Puducherry (2024)'
#   Extracted Name: 'KARAIKAL - PY2'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of  RTO GURDASPUR - PB6.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Punjab
#   Title in A1: 'Maker Month Wise Data  of  RTO GURDASPUR - PB6 , Punjab (2024)'
#   Extracted Name: 'RTO GURDASPUR - PB6'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of  RTO MOGA - PB29.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Punjab
#   Title in A1: 'Maker Month Wise Data  of  RTO MOGA - PB29 , Punjab (2024)'
#   Extracted Name: 'RTO MOGA - PB29'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of ABU ROAD DTO - RJ38.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Rajasthan
#   Title in A1: 'Maker Month Wise Data  of ABU ROAD DTO - RJ38 , Rajasthan (2024)'
#   Extracted Name: 'ABU ROAD DTO - RJ38'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of Agarwal Fitness Center - RJ225.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Rajasthan
#   Title in A1: 'Maker Month Wise Data  of Agarwal Fitness Center - RJ225 , Rajasthan (2024)'
#   Extracted Name: 'Agarwal Fitness Center - RJ225'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of GYALSING - SK2.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Sikkim
#   Title in A1: 'Maker Month Wise Data  of GYALSING - SK2 , Sikkim (2024)'
#   Extracted Name: 'GYALSING - SK2'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of NAMCHI - SK5.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Sikkim
#   Title in A1: 'Maker Month Wise Data  of NAMCHI - SK5 , Sikkim (2024)'
#   Extracted Name: 'NAMCHI - SK5'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of ALANGUDI UO - TN641.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Tamil Nadu
#   Title in A1: 'Maker Month Wise Data  of ALANGUDI UO - TN641 , Tamil Nadu (2024)'
#   Extracted Name: 'ALANGUDI UO - TN641'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of AMBATTUR RTO - TN612.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Tamil Nadu
#   Title in A1: 'Maker Month Wise Data  of AMBATTUR RTO - TN612 , Tamil Nadu (2024)'
#   Extracted Name: 'AMBATTUR RTO - TN612'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of DHALAI DTO - TR4.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Tripura
#   Title in A1: 'Maker Month Wise Data  of DHALAI DTO - TR4 , Tripura (2024)'
#   Extracted Name: 'DHALAI DTO - TR4'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of KHOWAI DTO - TR6.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Tripura
#   Title in A1: 'Maker Month Wise Data  of KHOWAI DTO - TR6 , Tripura (2024)'
#   Extracted Name: 'KHOWAI DTO - TR6'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of DAMAN - DD3.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\UT of DNH and DD
#   Title in A1: 'Maker Month Wise Data  of DAMAN - DD3 , UT of DNH and DD (2024)'
#   Extracted Name: 'DAMAN - DD3'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of SILVASSA - DD1.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\UT of DNH and DD
#   Title in A1: 'Maker Month Wise Data  of SILVASSA - DD1 , UT of DNH and DD (2024)'
#   Extracted Name: 'SILVASSA - DD1'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of Agra RTO - UP80.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Uttar Pradesh
#   Title in A1: 'Maker Month Wise Data  of Agra RTO - UP80 , Uttar Pradesh (2024)'
#   Extracted Name: 'Agra RTO - UP80'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of ALIGARH RTO - UP81.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Uttar Pradesh
#   Title in A1: 'Maker Month Wise Data  of ALIGARH RTO - UP81 , Uttar Pradesh (2024)'
#   Extracted Name: 'ALIGARH RTO - UP81'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of ALMORA RTO - UK1.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Uttarakhand
#   Title in A1: 'Maker Month Wise Data  of ALMORA RTO - UK1 , Uttarakhand (2024)'
#   Extracted Name: 'ALMORA RTO - UK1'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of DEHRADUN RTO - UK7.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Uttarakhand
#   Title in A1: 'Maker Month Wise Data  of DEHRADUN RTO - UK7 , Uttarakhand (2024)'
#   Extracted Name: 'DEHRADUN RTO - UK7'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of ALIPORE RTO - WB19.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\West Bengal
#   Title in A1: 'Maker Month Wise Data  of ALIPORE RTO - WB19 , West Bengal (2024)'
#   Extracted Name: 'ALIPORE RTO - WB19'
# ----------------------------------------------------------------------------------------------------
# File: Maker Month Wise Data  of ARAMBAG ARTO - WB18.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\West Bengal
#   Title in A1: 'Maker Month Wise Data  of ARAMBAG ARTO - WB18 , West Bengal (2024)'
#   Extracted Name: 'ARAMBAG ARTO - WB18'
# ----------------------------------------------------------------------------------------------------
#
# Processing 1445 files across 36 folders...
# DEBUG MODE: Processing 5 sample files first...
# Processing: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island\Maker Month Wise Data  of Baratang - AN201.xlsx
# Error: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island\Maker Month Wise Data  of Baratang - AN201.xlsx - [WinError 32] The process cannot access the file because it is being used by another process: 'F:\\Flipcarbon\\Ajax\\Maker\\Andaman & Nicobar Island\\Maker Month Wise Data  of Baratang - AN201.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Andaman & Nicobar Island\\Baratang - AN201.xlsx'
# Result: error
# Processing: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island\Maker Month Wise Data  of Car Nicobar - AN211.xlsx
# Result: success
# Processing: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island\Maker Month Wise Data  of Diglipur - AN204.xlsx
# Result: success
# Processing: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island\Maker Month Wise Data  of Ferrargunj - AN200.xlsx
# Result: success
# Processing: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island\Maker Month Wise Data  of Little Andaman  - AN207.xlsx
# Result: success
# Error: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island\Maker Month Wise Data  of Car Nicobar - AN211.xlsx - Excel read failed: [Errno 2] No such file or directory: 'F:\\Flipcarbon\\Ajax\\Maker\\Andaman & Nicobar Island\\Maker Month Wise Data  of Car Nicobar - AN211.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island\Maker Month Wise Data  of Diglipur - AN204.xlsx - Excel read failed: [Errno 2] No such file or directory: 'F:\\Flipcarbon\\Ajax\\Maker\\Andaman & Nicobar Island\\Maker Month Wise Data  of Diglipur - AN204.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island\Maker Month Wise Data  of Little Andaman  - AN207.xlsx - Excel read failed: [Errno 2] No such file or directory: 'F:\\Flipcarbon\\Ajax\\Maker\\Andaman & Nicobar Island\\Maker Month Wise Data  of Little Andaman  - AN207.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island\Maker Month Wise Data  of Ferrargunj - AN200.xlsx - Excel read failed: [Errno 2] No such file or directory: 'F:\\Flipcarbon\\Ajax\\Maker\\Andaman & Nicobar Island\\Maker Month Wise Data  of Ferrargunj - AN200.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island\Maker Month Wise Data  of Baratang - AN201.xlsx - [WinError 32] The process cannot access the file because it is being used by another process: 'F:\\Flipcarbon\\Ajax\\Maker\\Andaman & Nicobar Island\\Maker Month Wise Data  of Baratang - AN201.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Andaman & Nicobar Island\\Baratang - AN201.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island\~$Maker Month Wise Data  of Baratang - AN201.xlsx - Excel read failed: [Errno 13] Permission denied: 'F:\\Flipcarbon\\Ajax\\Maker\\Andaman & Nicobar Island\\~$Maker Month Wise Data  of Baratang - AN201.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Andhra Pradesh\Maker Month Wise Data  of Nandyal RTA - AP121_20250311224954.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Andhra Pradesh\\Maker Month Wise Data  of Nandyal RTA - AP121_20250311224954.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Andhra Pradesh\\Nandyal RTA - AP121.xlsx'
# Processed 50/1445 files (4.6s)
# Processed 100/1445 files (0.4s)
# Error: F:\Flipcarbon\Ajax\Maker\Assam\_27.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Assam\\_27.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Assam\\NIAIMT_20250311225323.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Assam\_28.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Assam\\_28.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Assam\\NIAIMT_20250311225323.xlsx'
# Processed 150/1445 files (0.6s)
# Error: F:\Flipcarbon\Ajax\Maker\Bihar\Maker Month Wise Data  of MUZAFFARPUR - BR6.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Bihar\\Maker Month Wise Data  of MUZAFFARPUR - BR6.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Bihar\\MUZAFFARPUR - BR6.xlsx'
# Processed 200/1445 files (0.5s)
# Error: F:\Flipcarbon\Ajax\Maker\Goa\Maker Month Wise Data  of DHARBANDORA RTO - GA12.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Goa\\Maker Month Wise Data  of DHARBANDORA RTO - GA12.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Goa\\DHARBANDORA RTO - GA12.xlsx'
# Processed 250/1445 files (0.6s)
# Processed 300/1445 files (0.7s)
# Processed 350/1445 files (0.4s)
# Processed 400/1445 files (0.3s)
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_124.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_124.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225326.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_123.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_123.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225326.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_125.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_125.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225326.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_126.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_126.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225326.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_127.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_127.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225326.xlsx'
# Processed 450/1445 files (0.5s)
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_128.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_128.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225326.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_131.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_131.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225326.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_129.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_129.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225326.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_130.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_130.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225326.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_132.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_132.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225326.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_135.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_135.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225326.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_134.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_134.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225326.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_133.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_133.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225326.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_136.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_136.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225326.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_137.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_137.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225326.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_138.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_138.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225326.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_168.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_168.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\SIRSA - HR24_20250311225326.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_166.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_166.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\TOHANA - HR23_20250311225326.xlsx'
# Processed 500/1445 files (0.3s)
# Processed 550/1445 files (0.4s)
# Error: F:\Flipcarbon\Ajax\Maker\Himachal Pradesh\_107.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Himachal Pradesh\\_107.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Himachal Pradesh\\RTO RAMPUR - HP92_20250311225327.xlsx'
# Processed 600/1445 files (0.4s)
# Error: F:\Flipcarbon\Ajax\Maker\Karnataka\Maker Month Wise Data  of BASAVAKALYAN ARTO - KA56_20250311225000.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Karnataka\\Maker Month Wise Data  of BASAVAKALYAN ARTO - KA56_20250311225000.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Karnataka\\BASAVAKALYAN ARTO - KA56.xlsx'
# Processed 650/1445 files (0.5s)
# Error: F:\Flipcarbon\Ajax\Maker\Karnataka\Maker Month Wise Data  of TIPTUR  ARTO - KA44_20250311225000.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Karnataka\\Maker Month Wise Data  of TIPTUR  ARTO - KA44_20250311225000.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Karnataka\\TIPTUR  ARTO - KA44.xlsx'
# Processed 700/1445 files (0.5s)
# Processed 750/1445 files (0.4s)
# Processed 800/1445 files (0.5s)
# Processed 850/1445 files (0.5s)
# Processed 900/1445 files (0.4s)
# Processed 950/1445 files (0.5s)
# Processed 1000/1445 files (0.5s)
# Processed 1050/1445 files (0.4s)
# Processed 1100/1445 files (0.4s)
# Processed 1150/1445 files (0.4s)
# Processed 1200/1445 files (0.4s)
# Error: F:\Flipcarbon\Ajax\Maker\Tamil Nadu\Maker Month Wise Data  of KARAIKUDI UO - TN602_20250311225005.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Tamil Nadu\\Maker Month Wise Data  of KARAIKUDI UO - TN602_20250311225005.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Tamil Nadu\\KARAIKUDI UO - TN602.xlsx'
# Processed 1250/1445 files (0.6s)
# Error: F:\Flipcarbon\Ajax\Maker\Tamil Nadu\Maker Month Wise Data  of ULUNDURPET RTO - TN577.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Tamil Nadu\\Maker Month Wise Data  of ULUNDURPET RTO - TN577.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Tamil Nadu\\ULUNDURPET RTO - TN577.xlsx'
# Processed 1300/1445 files (0.6s)
# Processed 1350/1445 files (0.6s)
# Processed 1400/1445 files (0.6s)
#
#
# Processing Summary:
# -------------------------------------------------------------------------------------
# Folder Path                                        |  Total | Success | Errors | Skipped
# -------------------------------------------------------------------------------------
# F:\Flipcarbon\Ajax\Maker                           |      0 |       0 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island  |      9 |       3 |      6 |       0
# F:\Flipcarbon\Ajax\Maker\Andhra Pradesh            |     75 |      74 |      1 |       0
# F:\Flipcarbon\Ajax\Maker\Arunachal Pradesh         |     26 |      26 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Assam                     |     34 |      32 |      2 |       0
# F:\Flipcarbon\Ajax\Maker\Bihar                     |     48 |      47 |      1 |       0
# F:\Flipcarbon\Ajax\Maker\Chandigarh                |      1 |       1 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Chhattisgarh              |     29 |      29 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Delhi                     |     22 |      22 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Goa                       |     12 |      11 |      1 |       0
# F:\Flipcarbon\Ajax\Maker\Gujarat                   |     34 |      34 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Haryana                   |    173 |     155 |     18 |       0
# F:\Flipcarbon\Ajax\Maker\Himachal Pradesh          |    112 |     111 |      1 |       0
# F:\Flipcarbon\Ajax\Maker\Jammu and Kashmir         |     18 |      18 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Jharkhand                 |     30 |      30 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Karnataka                 |     66 |      64 |      2 |       0
# F:\Flipcarbon\Ajax\Maker\Kerala                    |     80 |      80 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Ladakh                    |      1 |       1 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Lakshadweep               |      3 |       3 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Madhya Pradesh            |     46 |      46 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Maharashtra               |     53 |      53 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Manipur                   |     11 |      11 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Meghalaya                 |     10 |      10 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Mizoram                   |      8 |       8 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Nagaland                  |      6 |       6 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Odisha                    |     36 |      36 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Puducherry                |      7 |       7 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Punjab                    |     86 |      86 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Rajasthan                 |    121 |     121 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Sikkim                    |      5 |       5 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Tamil Nadu                |    131 |     129 |      2 |       0
# F:\Flipcarbon\Ajax\Maker\Tripura                   |      8 |       8 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\UT of DNH and DD          |      2 |       2 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Uttar Pradesh             |     74 |      74 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Uttarakhand               |     19 |      19 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\West Bengal               |     49 |      49 |      0 |       0
# -------------------------------------------------------------------------------------
# TOTALS                                             |   1445 |    1411 |     34 |       0
# -------------------------------------------------------------------------------------
#
# Total processing time: 17.94 seconds
# Log file: mass_excel_rename.log

# %%
import os
import time
import logging
import warnings
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor
import openpyxl

# Suppress style warnings
warnings.filterwarnings('ignore', category=UserWarning, module='openpyxl.styles.stylesheet')

# Configure logging
logging.basicConfig(
    filename='mass_excel_rename.log',
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

# Hardcoded path - MODIFY WITH YOUR SPECIFIC PATH
ROOT_DIR = r"F:\Flipcarbon\Ajax\Maker"

# Debug mode - set to True for verbose output
DEBUG_MODE = True

# Global collection for tracking errors
error_files = []

def fast_read_title(file_path):
    """Quickly read first cell using openpyxl without loading full file"""
    try:
        wb = openpyxl.load_workbook(file_path, read_only=True, data_only=True)
        sheet = wb.active
        title_value = sheet.cell(row=1, column=1).value
        
        # Handle None values
        if title_value is None:
            return ""
        return str(title_value)
    except Exception as e:
        logging.error(f"Excel read failed: {file_path}: {str(e)}")
        raise RuntimeError(f"Excel read failed: {str(e)}") from e
    finally:
        if 'wb' in locals():
            try:
                wb.close()
            except:
                pass  # Ignore errors on close

def extract_name_from_title(title, filename):
    """Extract just the location code from the title"""
    logging.info(f"Processing title: '{title}'")
    
    # Specific pattern extraction: Get just "Baratang - AN201" from 
    # "Maker Month Wise Data of Baratang - AN201 , Andaman & Nicobar Island (2024)"
    if "Maker Month Wise Data" in title:
        # Find the start position after "Maker Month Wise Data of "
        # Handle both "Maker Month Wise Data of" and "Maker Month Wise Data  of" (extra space)
        if "Maker Month Wise Data of " in title:
            start = title.find("Maker Month Wise Data of ") + len("Maker Month Wise Data of ")
        else:
            start = title.find("Maker Month Wise Data  of ") + len("Maker Month Wise Data  of ")
        
        # Find the comma after the location code
        end = title.find(",", start)
        if end != -1:
            return title[start:end].strip()
        else:
            # If no comma, try finding the state name in parentheses
            end = title.find(" (", start)
            if end != -1:
                return title[start:end].strip()
            else:
                # If no obvious delimiter, use the rest of the string
                return title[start:].strip()
    
    # Fallback - use original filename
    logging.warning(f"Could not extract name from title: '{title}', using original filename")
    return os.path.splitext(filename)[0]

def process_file(args):
    """Process a single file with enhanced error handling and debugging"""
    folder, filename = args
    file_path = os.path.join(folder, filename)
    original_name, ext = os.path.splitext(filename)
    
    try:
        # Read title from Excel file
        title = fast_read_title(file_path)
        
        if DEBUG_MODE:
            logging.info(f"File: {filename}, Title: '{title}'")
            if not title:
                logging.warning(f"Empty title in file: {filename}")
        
        # Extract just the location code
        new_name = extract_name_from_title(title, filename)
        
        # Clean the new name
        new_name = new_name.replace('/', '-').replace('\\', '-').strip()
        if not new_name:
            raise ValueError("Failed to extract a valid name")
            
        new_filename = f"{new_name}{ext}"
        new_path = os.path.join(folder, new_filename)
        
        if DEBUG_MODE:
            logging.info(f"Extracted name: '{new_name}' for file: {filename}")
        
        # Skip if no change needed
        if new_filename == filename:
            return (folder, "skipped (same name)")
            
        if os.path.exists(new_path):
            # Add timestamp to make unique
            timestamp = datetime.now().strftime("%Y%m%d%H%M%S")
            new_filename = f"{new_name}_{timestamp}{ext}"
            new_path = os.path.join(folder, new_filename)
            logging.warning(f"Duplicate name, adding timestamp: {new_filename}")
            
        # Perform the rename
        os.rename(file_path, new_path)
        return (folder, "success")

    except Exception as e:
        error_msg = f"{file_path} - {str(e)}"
        logging.error(error_msg)
        # Add to global error tracking
        error_files.append({
            'folder': folder,
            'filename': filename,
            'error': str(e)
        })
        
        if DEBUG_MODE:
            print(f"Error: {error_msg}")
        return (folder, "error")

def process_folder(max_workers=4):
    """Process files in parallel with thread pool"""
    folder_stats = {}
    
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Collect all files first for accurate progress
        file_count = 0
        all_files = []
        for folder, _, files in os.walk(ROOT_DIR):
            excel_files = [f for f in files if f.lower().endswith(('.xlsx', '.xls'))]
            all_files.extend([(folder, f) for f in excel_files])
            folder_stats[folder] = {
                'total': len(excel_files),
                'success': 0,
                'error': 0,
                'skipped': 0
            }
        file_count = len(all_files)
        
        # Process files with progress updates
        start_time = time.time()
        processed = 0
        print(f"\nProcessing {file_count} files across {len(folder_stats)} folders...")
        
        # For debugging, process just a few files first
        if DEBUG_MODE:
            test_files = all_files[:5] if len(all_files) > 5 else all_files
            print(f"DEBUG MODE: Processing {len(test_files)} sample files first...")
            
            for file_args in test_files:
                folder, filename = file_args
                print(f"Processing: {os.path.join(folder, filename)}")
                result = process_file(file_args)
                print(f"Result: {result[1]}")
            
            proceed = input("Continue with all files? (y/n): ").lower() == 'y'
            if not proceed:
                print("Operation cancelled by user")
                return folder_stats
        
        # Process all files
        for result in executor.map(process_file, all_files):
            folder, status = result
            status_key = status.split()[0]  # Get first word (success, error, skipped)
            folder_stats[folder][status_key] += 1
            processed += 1
            
            # Progress update every 50 files or 5 seconds
            if processed % 50 == 0 or (time.time() - start_time) > 5:
                elapsed = time.time() - start_time
                print(f"Processed {processed}/{file_count} files ({elapsed:.1f}s)")
                start_time = time.time()  # Reset timer

    return folder_stats

def print_stats(folder_stats):
    """Print detailed statistics table"""
    print("\n\nProcessing Summary:")
    print("-" * 85)
    print(f"{'Folder Path':<50} | {'Total':>6} | {'Success':>7} | {'Errors':>6} | {'Skipped':>7}")
    print("-" * 85)
    
    for folder, stats in sorted(folder_stats.items()):
        print(f"{folder:<50} | {stats['total']:>6} | {stats['success']:>7} | "
              f"{stats['error']:>6} | {stats['skipped']:>7}")
    
    totals = {
        'total': sum(s['total'] for s in folder_stats.values()),
        'success': sum(s['success'] for s in folder_stats.values()),
        'error': sum(s['error'] for s in folder_stats.values()),
        'skipped': sum(s['skipped'] for s in folder_stats.values())
    }
    
    print("-" * 85)
    print(f"{'TOTALS':<50} | {totals['total']:>6} | {totals['success']:>7} | "
          f"{totals['error']:>6} | {totals['skipped']:>7}")
    print("-" * 85)

def export_error_list():
    """Export the list of error files to a CSV file"""
    if not error_files:
        print("No errors to export!")
        return
        
    # Create error report
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    report_file = f"error_files_{timestamp}.csv"
    
    with open(report_file, 'w') as f:
        f.write("Folder,Filename,Error\n")
        for error in error_files:
            # Clean up any commas in error messages to prevent CSV issues
            safe_error = error['error'].replace(',', ' ')
            f.write(f"{error['folder']},{error['filename']},{safe_error}\n")
    
    print(f"\nError file list exported to: {report_file}")
    print(f"Total error files: {len(error_files)}")
    
    # Also display the first 10 errors on screen
    if error_files:
        print("\nSample of Error Files:")
        print("-" * 100)
        for i, error in enumerate(error_files[:10]):
            print(f"{i+1}. {os.path.join(error['folder'], error['filename'])}")
            print(f"   Error: {error['error']}")
        
        if len(error_files) > 10:
            print(f"...and {len(error_files) - 10} more. See {report_file} for complete list.")

def analyze_sample_files():
    """Analyze a few sample files to debug title extraction issues"""
    print("\nSample File Analysis:")
    print("-" * 100)
    
    for folder, _, files in os.walk(ROOT_DIR):
        excel_files = [f for f in files if f.lower().endswith(('.xlsx', '.xls'))]
        if not excel_files:
            continue
            
        # Take up to 2 files from each folder for analysis
        sample_files = excel_files[:2]
        for filename in sample_files:
            file_path = os.path.join(folder, filename)
            try:
                title = fast_read_title(file_path)
                new_name = extract_name_from_title(title, filename)
                
                print(f"File: {filename}")
                print(f"  Path: {folder}")
                print(f"  Title in A1: '{title}'")
                print(f"  Extracted Name: '{new_name}'")
                print("-" * 100)
                
            except Exception as e:
                print(f"File: {filename}")
                print(f"  Path: {folder}")
                print(f"  ERROR: {str(e)}")
                print("-" * 100)

if __name__ == "__main__":
    # Validate path before processing
    if not os.path.isdir(ROOT_DIR):
        print(f"Error: Path does not exist or is not a directory\n{ROOT_DIR}")
        exit(1)
    
    print(f"Starting processing for:\n{ROOT_DIR}")
    
    # First analyze sample files if in debug mode
    if DEBUG_MODE:
        choice = input("Run sample analysis first? (y/n): ").lower()
        if choice == 'y':
            analyze_sample_files()
    
    # Start the main processing
    start = time.time()
    stats = process_folder()
    duration = time.time() - start
    
    print_stats(stats)
    
    # Export error files list
    export_error_list()
    
    print(f"\nTotal processing time: {duration:.2f} seconds")
    print(f"Log file: mass_excel_rename.log")
# Out:
# Starting processing for:
# F:\Flipcarbon\Ajax\Maker
#
# Sample File Analysis:
# ----------------------------------------------------------------------------------------------------
# File: Car Nicobar - AN211.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island
#   Title in A1: 'Maker Month Wise Data  of Car Nicobar - AN211 , Andaman & Nicobar Island (2024)'
#   Extracted Name: 'Car Nicobar - AN211'
# ----------------------------------------------------------------------------------------------------
# File: Diglipur - AN204.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island
#   Title in A1: 'Maker Month Wise Data  of Diglipur - AN204 , Andaman & Nicobar Island (2024)'
#   Extracted Name: 'Diglipur - AN204'
# ----------------------------------------------------------------------------------------------------
# File: Adoni RTO - AP221.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Andhra Pradesh
#   Title in A1: 'Maker Month Wise Data  of Adoni RTO - AP221 , Andhra Pradesh (2024)'
#   Extracted Name: 'Adoni RTO - AP221'
# ----------------------------------------------------------------------------------------------------
# File: Amalapuram RTA - AP205.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Andhra Pradesh
#   Title in A1: 'Maker Month Wise Data  of Amalapuram RTA - AP205 , Andhra Pradesh (2024)'
#   Extracted Name: 'Amalapuram RTA - AP205'
# ----------------------------------------------------------------------------------------------------
# File: ANJAW - AR17.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Arunachal Pradesh
#   Title in A1: 'Maker Month Wise Data  of ANJAW - AR17 , Arunachal Pradesh (2024)'
#   Extracted Name: 'ANJAW - AR17'
# ----------------------------------------------------------------------------------------------------
# File: CHANGLANG - AR12.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Arunachal Pradesh
#   Title in A1: 'Maker Month Wise Data  of CHANGLANG - AR12 , Arunachal Pradesh (2024)'
#   Extracted Name: 'CHANGLANG - AR12'
# ----------------------------------------------------------------------------------------------------
# File: BARPETA - AS15.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Assam
#   Title in A1: 'Maker Month Wise Data  of BARPETA - AS15 , Assam (2024)'
#   Extracted Name: 'BARPETA - AS15'
# ----------------------------------------------------------------------------------------------------
# File: BISWANATH CHARIALI - AS32.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Assam
#   Title in A1: 'Maker Month Wise Data  of BISWANATH CHARIALI - AS32 , Assam (2024)'
#   Extracted Name: 'BISWANATH CHARIALI - AS32'
# ----------------------------------------------------------------------------------------------------
# File: ARARIA - BR38.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Bihar
#   Title in A1: 'Maker Month Wise Data  of ARARIA - BR38 , Bihar (2024)'
#   Extracted Name: 'ARARIA - BR38'
# ----------------------------------------------------------------------------------------------------
# File: AURANGABAD - BR26.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Bihar
#   Title in A1: 'Maker Month Wise Data  of AURANGABAD - BR26 , Bihar (2024)'
#   Extracted Name: 'AURANGABAD - BR26'
# ----------------------------------------------------------------------------------------------------
# File: CHANDIGARH UT (RLA AND STA) - CH1.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Chandigarh
#   Title in A1: 'Maker Month Wise Data  of CHANDIGARH UT (RLA AND STA) - CH1 , Chandigarh (2024)'
#   Extracted Name: 'CHANDIGARH UT (RLA AND STA) - CH1'
# ----------------------------------------------------------------------------------------------------
# File: Ambikapur RTO - CG15.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Chhattisgarh
#   Title in A1: 'Maker Month Wise Data  of Ambikapur RTO - CG15 , Chhattisgarh (2024)'
#   Extracted Name: 'Ambikapur RTO - CG15'
# ----------------------------------------------------------------------------------------------------
# File: Balod DTO - CG24.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Chhattisgarh
#   Title in A1: 'Maker Month Wise Data  of Balod DTO - CG24 , Chhattisgarh (2024)'
#   Extracted Name: 'Balod DTO - CG24'
# ----------------------------------------------------------------------------------------------------
# File: BURARI AUTO UNIT - DL53.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Delhi
#   Title in A1: 'Maker Month Wise Data  of BURARI AUTO UNIT - DL53 , Delhi (2024)'
#   Extracted Name: 'BURARI AUTO UNIT - DL53'
# ----------------------------------------------------------------------------------------------------
# File: BURARI TAXI UNIT - DL52.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Delhi
#   Title in A1: 'Maker Month Wise Data  of BURARI TAXI UNIT - DL52 , Delhi (2024)'
#   Extracted Name: 'BURARI TAXI UNIT - DL52'
# ----------------------------------------------------------------------------------------------------
# File: ASSISTANT DIRECTOR OF TRANSPORT ENF. (NORTH) PANAJI - GA107.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Goa
#   Title in A1: 'Maker Month Wise Data  of ASSISTANT DIRECTOR OF TRANSPORT ENF. (NORTH) PANAJI - GA107 , Goa (2024)'
#   Extracted Name: 'ASSISTANT DIRECTOR OF TRANSPORT ENF. (NORTH) PANAJI - GA107'
# ----------------------------------------------------------------------------------------------------
# File: BICHOLIM RTO - GA4.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Goa
#   Title in A1: 'Maker Month Wise Data  of BICHOLIM RTO - GA4 , Goa (2024)'
#   Extracted Name: 'BICHOLIM RTO - GA4'
# ----------------------------------------------------------------------------------------------------
# File: AAHWA - GJ30.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Gujarat
#   Title in A1: 'Maker Month Wise Data  of AAHWA - GJ30 , Gujarat (2024)'
#   Extracted Name: 'AAHWA - GJ30'
# ----------------------------------------------------------------------------------------------------
# File: Ahmedabad (Rural).xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Gujarat
#   Title in A1: 'Maker Month Wise Data  of Ahmedabad (Rural), Bawla ARTO - GJ38 , Gujarat (2024)'
#   Extracted Name: 'Ahmedabad (Rural)'
# ----------------------------------------------------------------------------------------------------
# File: AMBALA CITY - HR1.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Haryana
#   Title in A1: 'Maker Month Wise Data  of AMBALA CITY - HR1 , Haryana (2024)'
#   Extracted Name: 'AMBALA CITY - HR1'
# ----------------------------------------------------------------------------------------------------
# File: BAHADURGARH - HR13.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Haryana
#   Title in A1: 'Maker Month Wise Data  of BAHADURGARH - HR13 , Haryana (2024)'
#   Extracted Name: 'BAHADURGARH - HR13'
# ----------------------------------------------------------------------------------------------------
# File: HRTC BAIJNATH - HP113.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Himachal Pradesh
#   Title in A1: 'Maker Month Wise Data  of HRTC BAIJNATH - HP113 , Himachal Pradesh (2024)'
#   Extracted Name: 'HRTC BAIJNATH - HP113'
# ----------------------------------------------------------------------------------------------------
# File: HRTC CHAMBA - HP115.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Himachal Pradesh
#   Title in A1: 'Maker Month Wise Data  of HRTC CHAMBA - HP115 , Himachal Pradesh (2024)'
#   Extracted Name: 'HRTC CHAMBA - HP115'
# ----------------------------------------------------------------------------------------------------
# File: ANANTNAG ARTO - JK3.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Jammu and Kashmir
#   Title in A1: 'Maker Month Wise Data  of ANANTNAG ARTO - JK3 , Jammu and Kashmir (2024)'
#   Extracted Name: 'ANANTNAG ARTO - JK3'
# ----------------------------------------------------------------------------------------------------
# File: DODA ARTO - JK6.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Jammu and Kashmir
#   Title in A1: 'Maker Month Wise Data  of DODA ARTO - JK6 , Jammu and Kashmir (2024)'
#   Extracted Name: 'DODA ARTO - JK6'
# ----------------------------------------------------------------------------------------------------
# File: Authorised Testing  Centre (TUV SUD).xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Jharkhand
#   Title in A1: 'Maker Month Wise Data  of Authorised Testing  Centre (TUV SUD), Ranchi - JH201 , Jharkhand (2024)'
#   Extracted Name: 'Authorised Testing  Centre (TUV SUD)'
# ----------------------------------------------------------------------------------------------------
# File: BOKARO - JH9.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Jharkhand
#   Title in A1: 'Maker Month Wise Data  of BOKARO - JH9 , Jharkhand (2024)'
#   Extracted Name: 'BOKARO - JH9'
# ----------------------------------------------------------------------------------------------------
# File: ATHANI ARTO - KA71.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Karnataka
#   Title in A1: 'Maker Month Wise Data  of ATHANI ARTO - KA71 , Karnataka (2024)'
#   Extracted Name: 'ATHANI ARTO - KA71'
# ----------------------------------------------------------------------------------------------------
# File: BAILHONGAL  RTO - KA24.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Karnataka
#   Title in A1: 'Maker Month Wise Data  of BAILHONGAL  RTO - KA24 , Karnataka (2024)'
#   Extracted Name: 'BAILHONGAL  RTO - KA24'
# ----------------------------------------------------------------------------------------------------
# File: ADOOR SRTO - KL26.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Kerala
#   Title in A1: 'Maker Month Wise Data  of ADOOR SRTO - KL26 , Kerala (2024)'
#   Extracted Name: 'ADOOR SRTO - KL26'
# ----------------------------------------------------------------------------------------------------
# File: ALATHUR SRTO - KL49.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Kerala
#   Title in A1: 'Maker Month Wise Data  of ALATHUR SRTO - KL49 , Kerala (2024)'
#   Extracted Name: 'ALATHUR SRTO - KL49'
# ----------------------------------------------------------------------------------------------------
# File: KARGIL ARTO - LA1.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Ladakh
#   Title in A1: 'Maker Month Wise Data  of KARGIL ARTO - LA1 , Ladakh (2024)'
#   Extracted Name: 'KARGIL ARTO - LA1'
# ----------------------------------------------------------------------------------------------------
# File: AMINI - LD3.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Lakshadweep
#   Title in A1: 'Maker Month Wise Data  of AMINI - LD3 , Lakshadweep (2024)'
#   Extracted Name: 'AMINI - LD3'
# ----------------------------------------------------------------------------------------------------
# File: KAVARATTI - LD1.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Lakshadweep
#   Title in A1: 'Maker Month Wise Data  of KAVARATTI - LD1 , Lakshadweep (2024)'
#   Extracted Name: 'KAVARATTI - LD1'
# ----------------------------------------------------------------------------------------------------
# File: AGAR MALWA RTO - MP70.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Madhya Pradesh
#   Title in A1: 'Maker Month Wise Data  of AGAR MALWA RTO - MP70 , Madhya Pradesh (2024)'
#   Extracted Name: 'AGAR MALWA RTO - MP70'
# ----------------------------------------------------------------------------------------------------
# File: ASHOKNAGAR DTO - MP67.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Madhya Pradesh
#   Title in A1: 'Maker Month Wise Data  of ASHOKNAGAR DTO - MP67 , Madhya Pradesh (2024)'
#   Extracted Name: 'ASHOKNAGAR DTO - MP67'
# ----------------------------------------------------------------------------------------------------
# File: AKLUJ - MH45.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Maharashtra
#   Title in A1: 'Maker Month Wise Data  of AKLUJ - MH45 , Maharashtra (2024)'
#   Extracted Name: 'AKLUJ - MH45'
# ----------------------------------------------------------------------------------------------------
# File: AMRAWATI - MH27.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Maharashtra
#   Title in A1: 'Maker Month Wise Data  of AMRAWATI - MH27 , Maharashtra (2024)'
#   Extracted Name: 'AMRAWATI - MH27'
# ----------------------------------------------------------------------------------------------------
# File: BISHNUPUR - MN5.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Manipur
#   Title in A1: 'Maker Month Wise Data  of BISHNUPUR - MN5 , Manipur (2024)'
#   Extracted Name: 'BISHNUPUR - MN5'
# ----------------------------------------------------------------------------------------------------
# File: CHURACHANDPUR - MN2.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Manipur
#   Title in A1: 'Maker Month Wise Data  of CHURACHANDPUR - MN2 , Manipur (2024)'
#   Extracted Name: 'CHURACHANDPUR - MN2'
# ----------------------------------------------------------------------------------------------------
# File: AMPATI - ML14.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Meghalaya
#   Title in A1: 'Maker Month Wise Data  of AMPATI - ML14 , Meghalaya (2024)'
#   Extracted Name: 'AMPATI - ML14'
# ----------------------------------------------------------------------------------------------------
# File: KHLIEHRIAT - ML11.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Meghalaya
#   Title in A1: 'Maker Month Wise Data  of KHLIEHRIAT - ML11 , Meghalaya (2024)'
#   Extracted Name: 'KHLIEHRIAT - ML11'
# ----------------------------------------------------------------------------------------------------
# File: AIZAWL DTO - MZ1.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Mizoram
#   Title in A1: 'Maker Month Wise Data  of AIZAWL DTO - MZ1 , Mizoram (2024)'
#   Extracted Name: 'AIZAWL DTO - MZ1'
# ----------------------------------------------------------------------------------------------------
# File: CHAMPHAI - MZ4.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Mizoram
#   Title in A1: 'Maker Month Wise Data  of CHAMPHAI - MZ4 , Mizoram (2024)'
#   Extracted Name: 'CHAMPHAI - MZ4'
# ----------------------------------------------------------------------------------------------------
# File: DIMAPUR DTO - NL7.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Nagaland
#   Title in A1: 'Maker Month Wise Data  of DIMAPUR DTO - NL7 , Nagaland (2024)'
#   Extracted Name: 'DIMAPUR DTO - NL7'
# ----------------------------------------------------------------------------------------------------
# File: MON DTO - NL4.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Nagaland
#   Title in A1: 'Maker Month Wise Data  of MON DTO - NL4 , Nagaland (2024)'
#   Extracted Name: 'MON DTO - NL4'
# ----------------------------------------------------------------------------------------------------
# File: ANGUL RTO - OD19.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Odisha
#   Title in A1: 'Maker Month Wise Data  of ANGUL RTO - OD19 , Odisha (2024)'
#   Extracted Name: 'ANGUL RTO - OD19'
# ----------------------------------------------------------------------------------------------------
# File: BALASORE RTO - OD1.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Odisha
#   Title in A1: 'Maker Month Wise Data  of BALASORE RTO - OD1 , Odisha (2024)'
#   Extracted Name: 'BALASORE RTO - OD1'
# ----------------------------------------------------------------------------------------------------
# File: BAHOUR - PY11.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Puducherry
#   Title in A1: 'Maker Month Wise Data  of BAHOUR - PY11 , Puducherry (2024)'
#   Extracted Name: 'BAHOUR - PY11'
# ----------------------------------------------------------------------------------------------------
# File: KARAIKAL - PY2.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Puducherry
#   Title in A1: 'Maker Month Wise Data  of KARAIKAL - PY2 , Puducherry (2024)'
#   Extracted Name: 'KARAIKAL - PY2'
# ----------------------------------------------------------------------------------------------------
# File: PUNJAB STA(RAC)-(AITP) - PB1.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Punjab
#   Title in A1: 'Maker Month Wise Data  of PUNJAB STA(RAC)/(AITP) - PB1 , Punjab (2024)'
#   Extracted Name: 'PUNJAB STA(RAC)/(AITP) - PB1'
# ----------------------------------------------------------------------------------------------------
# File: RTO FARIDKOT  - PB4.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Punjab
#   Title in A1: 'Maker Month Wise Data  of RTO FARIDKOT  - PB4 , Punjab (2024)'
#   Extracted Name: 'RTO FARIDKOT  - PB4'
# ----------------------------------------------------------------------------------------------------
# File: ABU ROAD DTO - RJ38.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Rajasthan
#   Title in A1: 'Maker Month Wise Data  of ABU ROAD DTO - RJ38 , Rajasthan (2024)'
#   Extracted Name: 'ABU ROAD DTO - RJ38'
# ----------------------------------------------------------------------------------------------------
# File: Agarwal Fitness Center - RJ225.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Rajasthan
#   Title in A1: 'Maker Month Wise Data  of Agarwal Fitness Center - RJ225 , Rajasthan (2024)'
#   Extracted Name: 'Agarwal Fitness Center - RJ225'
# ----------------------------------------------------------------------------------------------------
# File: GYALSING - SK2.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Sikkim
#   Title in A1: 'Maker Month Wise Data  of GYALSING - SK2 , Sikkim (2024)'
#   Extracted Name: 'GYALSING - SK2'
# ----------------------------------------------------------------------------------------------------
# File: NAMCHI - SK5.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Sikkim
#   Title in A1: 'Maker Month Wise Data  of NAMCHI - SK5 , Sikkim (2024)'
#   Extracted Name: 'NAMCHI - SK5'
# ----------------------------------------------------------------------------------------------------
# File: ALANGUDI UO - TN641.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Tamil Nadu
#   Title in A1: 'Maker Month Wise Data  of ALANGUDI UO - TN641 , Tamil Nadu (2024)'
#   Extracted Name: 'ALANGUDI UO - TN641'
# ----------------------------------------------------------------------------------------------------
# File: AMBATTUR RTO - TN612.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Tamil Nadu
#   Title in A1: 'Maker Month Wise Data  of AMBATTUR RTO - TN612 , Tamil Nadu (2024)'
#   Extracted Name: 'AMBATTUR RTO - TN612'
# ----------------------------------------------------------------------------------------------------
# File: DHALAI DTO - TR4.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Tripura
#   Title in A1: 'Maker Month Wise Data  of DHALAI DTO - TR4 , Tripura (2024)'
#   Extracted Name: 'DHALAI DTO - TR4'
# ----------------------------------------------------------------------------------------------------
# File: KHOWAI DTO - TR6.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Tripura
#   Title in A1: 'Maker Month Wise Data  of KHOWAI DTO - TR6 , Tripura (2024)'
#   Extracted Name: 'KHOWAI DTO - TR6'
# ----------------------------------------------------------------------------------------------------
# File: DAMAN - DD3.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\UT of DNH and DD
#   Title in A1: 'Maker Month Wise Data  of DAMAN - DD3 , UT of DNH and DD (2024)'
#   Extracted Name: 'DAMAN - DD3'
# ----------------------------------------------------------------------------------------------------
# File: SILVASSA - DD1.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\UT of DNH and DD
#   Title in A1: 'Maker Month Wise Data  of SILVASSA - DD1 , UT of DNH and DD (2024)'
#   Extracted Name: 'SILVASSA - DD1'
# ----------------------------------------------------------------------------------------------------
# File: Agra RTO - UP80.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Uttar Pradesh
#   Title in A1: 'Maker Month Wise Data  of Agra RTO - UP80 , Uttar Pradesh (2024)'
#   Extracted Name: 'Agra RTO - UP80'
# ----------------------------------------------------------------------------------------------------
# File: ALIGARH RTO - UP81.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Uttar Pradesh
#   Title in A1: 'Maker Month Wise Data  of ALIGARH RTO - UP81 , Uttar Pradesh (2024)'
#   Extracted Name: 'ALIGARH RTO - UP81'
# ----------------------------------------------------------------------------------------------------
# File: ALMORA RTO - UK1.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Uttarakhand
#   Title in A1: 'Maker Month Wise Data  of ALMORA RTO - UK1 , Uttarakhand (2024)'
#   Extracted Name: 'ALMORA RTO - UK1'
# ----------------------------------------------------------------------------------------------------
# File: DEHRADUN RTO - UK7.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\Uttarakhand
#   Title in A1: 'Maker Month Wise Data  of DEHRADUN RTO - UK7 , Uttarakhand (2024)'
#   Extracted Name: 'DEHRADUN RTO - UK7'
# ----------------------------------------------------------------------------------------------------
# File: ALIPORE RTO - WB19.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\West Bengal
#   Title in A1: 'Maker Month Wise Data  of ALIPORE RTO - WB19 , West Bengal (2024)'
#   Extracted Name: 'ALIPORE RTO - WB19'
# ----------------------------------------------------------------------------------------------------
# File: ARAMBAG ARTO - WB18.xlsx
#   Path: F:\Flipcarbon\Ajax\Maker\West Bengal
#   Title in A1: 'Maker Month Wise Data  of ARAMBAG ARTO - WB18 , West Bengal (2024)'
#   Extracted Name: 'ARAMBAG ARTO - WB18'
# ----------------------------------------------------------------------------------------------------
#
# Processing 1444 files across 36 folders...
# DEBUG MODE: Processing 5 sample files first...
# Processing: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island\Car Nicobar - AN211.xlsx
# Result: skipped (same name)
# Processing: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island\Diglipur - AN204.xlsx
# Result: skipped (same name)
# Processing: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island\Ferrargunj - AN200.xlsx
# Result: skipped (same name)
# Processing: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island\Little Andaman  - AN207.xlsx
# Result: skipped (same name)
# Processing: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island\Maker Month Wise Data  of Baratang - AN201.xlsx
# Result: success
# Error: F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island\Maker Month Wise Data  of Baratang - AN201.xlsx - Excel read failed: [Errno 2] No such file or directory: 'F:\\Flipcarbon\\Ajax\\Maker\\Andaman & Nicobar Island\\Maker Month Wise Data  of Baratang - AN201.xlsx'
# Processed 50/1444 files (2.0s)
# Processed 100/1444 files (0.5s)
# Error: F:\Flipcarbon\Ajax\Maker\Assam\_27.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Assam\\_27.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Assam\\NIAIMT_20250311225648.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Assam\_28.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Assam\\_28.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Assam\\NIAIMT_20250311225648.xlsx'
# Processed 150/1444 files (0.6s)
# Processed 200/1444 files (0.6s)
# Processed 250/1444 files (0.5s)
# Processed 300/1444 files (0.6s)
# Processed 350/1444 files (0.4s)
# Processed 400/1444 files (0.3s)
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_123.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_123.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'Error: F:\Flipcarbon\Ajax\Maker\Haryana\_126.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_126.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
#
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_124.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_124.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_128.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_128.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_125.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_125.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_129.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_129.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_127.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_127.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# Processed 450/1444 files (0.6s)
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_130.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_130.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_131.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_131.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_133.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_133.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_132.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_132.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_136.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_136.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_134.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_134.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_135.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_135.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_137.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_137.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_138.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_138.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_166.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_166.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\TOHANA - HR23_20250311225651.xlsx'
# Error: F:\Flipcarbon\Ajax\Maker\Haryana\_168.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_168.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\SIRSA - HR24_20250311225651.xlsx'
# Processed 500/1444 files (0.4s)
# Processed 550/1444 files (0.5s)
# Error: F:\Flipcarbon\Ajax\Maker\Himachal Pradesh\_107.xlsx - [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Himachal Pradesh\\_107.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Himachal Pradesh\\RTO RAMPUR - HP92_20250311225652.xlsx'
# Processed 600/1444 files (0.5s)
# Processed 650/1444 files (0.5s)
# Processed 700/1444 files (0.6s)
# Processed 750/1444 files (0.6s)
# Processed 800/1444 files (0.6s)
# Processed 850/1444 files (0.7s)
# Processed 900/1444 files (0.5s)
# Processed 950/1444 files (0.6s)
# Processed 1000/1444 files (0.5s)
# Processed 1050/1444 files (0.4s)
# Processed 1100/1444 files (0.5s)
# Processed 1150/1444 files (0.4s)
# Processed 1200/1444 files (0.6s)
# Processed 1250/1444 files (0.5s)
# Processed 1300/1444 files (0.6s)
# Processed 1350/1444 files (0.7s)
# Processed 1400/1444 files (0.6s)
#
#
# Processing Summary:
# -------------------------------------------------------------------------------------
# Folder Path                                        |  Total | Success | Errors | Skipped
# -------------------------------------------------------------------------------------
# F:\Flipcarbon\Ajax\Maker                           |      0 |       0 |      0 |       0
# F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island  |      8 |       1 |      1 |       6
# F:\Flipcarbon\Ajax\Maker\Andhra Pradesh            |     75 |       3 |      0 |      72
# F:\Flipcarbon\Ajax\Maker\Arunachal Pradesh         |     26 |       2 |      0 |      24
# F:\Flipcarbon\Ajax\Maker\Assam                     |     34 |       3 |      2 |      29
# F:\Flipcarbon\Ajax\Maker\Bihar                     |     48 |       7 |      0 |      41
# F:\Flipcarbon\Ajax\Maker\Chandigarh                |      1 |       0 |      0 |       1
# F:\Flipcarbon\Ajax\Maker\Chhattisgarh              |     29 |       5 |      0 |      24
# F:\Flipcarbon\Ajax\Maker\Delhi                     |     22 |       3 |      0 |      19
# F:\Flipcarbon\Ajax\Maker\Goa                       |     12 |       1 |      0 |      11
# F:\Flipcarbon\Ajax\Maker\Gujarat                   |     34 |       4 |      0 |      30
# F:\Flipcarbon\Ajax\Maker\Haryana                   |    173 |       9 |     18 |     146
# F:\Flipcarbon\Ajax\Maker\Himachal Pradesh          |    112 |      16 |      1 |      95
# F:\Flipcarbon\Ajax\Maker\Jammu and Kashmir         |     18 |       1 |      0 |      17
# F:\Flipcarbon\Ajax\Maker\Jharkhand                 |     30 |       3 |      0 |      27
# F:\Flipcarbon\Ajax\Maker\Karnataka                 |     66 |      11 |      0 |      55
# F:\Flipcarbon\Ajax\Maker\Kerala                    |     80 |       6 |      0 |      74
# F:\Flipcarbon\Ajax\Maker\Ladakh                    |      1 |       0 |      0 |       1
# F:\Flipcarbon\Ajax\Maker\Lakshadweep               |      3 |       0 |      0 |       3
# F:\Flipcarbon\Ajax\Maker\Madhya Pradesh            |     46 |       0 |      0 |      46
# F:\Flipcarbon\Ajax\Maker\Maharashtra               |     53 |       4 |      0 |      49
# F:\Flipcarbon\Ajax\Maker\Manipur                   |     11 |       0 |      0 |      11
# F:\Flipcarbon\Ajax\Maker\Meghalaya                 |     10 |       0 |      0 |      10
# F:\Flipcarbon\Ajax\Maker\Mizoram                   |      8 |       0 |      0 |       8
# F:\Flipcarbon\Ajax\Maker\Nagaland                  |      6 |       0 |      0 |       6
# F:\Flipcarbon\Ajax\Maker\Odisha                    |     36 |       1 |      0 |      35
# F:\Flipcarbon\Ajax\Maker\Puducherry                |      7 |       0 |      0 |       7
# F:\Flipcarbon\Ajax\Maker\Punjab                    |     86 |       1 |      0 |      85
# F:\Flipcarbon\Ajax\Maker\Rajasthan                 |    121 |       3 |      0 |     118
# F:\Flipcarbon\Ajax\Maker\Sikkim                    |      5 |       0 |      0 |       5
# F:\Flipcarbon\Ajax\Maker\Tamil Nadu                |    131 |      12 |      0 |     119
# F:\Flipcarbon\Ajax\Maker\Tripura                   |      8 |       0 |      0 |       8
# F:\Flipcarbon\Ajax\Maker\UT of DNH and DD          |      2 |       0 |      0 |       2
# F:\Flipcarbon\Ajax\Maker\Uttar Pradesh             |     74 |       7 |      0 |      67
# F:\Flipcarbon\Ajax\Maker\Uttarakhand               |     19 |       2 |      0 |      17
# F:\Flipcarbon\Ajax\Maker\West Bengal               |     49 |       2 |      0 |      47
# -------------------------------------------------------------------------------------
# TOTALS                                             |   1444 |     107 |     22 |    1315
# -------------------------------------------------------------------------------------
#
# Error file list exported to: error_files_20250311_225702.csv
# Total error files: 22
#
# Sample of Error Files:
# ----------------------------------------------------------------------------------------------------
# 1. F:\Flipcarbon\Ajax\Maker\Andaman & Nicobar Island\Maker Month Wise Data  of Baratang - AN201.xlsx
#    Error: Excel read failed: [Errno 2] No such file or directory: 'F:\\Flipcarbon\\Ajax\\Maker\\Andaman & Nicobar Island\\Maker Month Wise Data  of Baratang - AN201.xlsx'
# 2. F:\Flipcarbon\Ajax\Maker\Assam\_27.xlsx
#    Error: [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Assam\\_27.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Assam\\NIAIMT_20250311225648.xlsx'
# 3. F:\Flipcarbon\Ajax\Maker\Assam\_28.xlsx
#    Error: [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Assam\\_28.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Assam\\NIAIMT_20250311225648.xlsx'
# 4. F:\Flipcarbon\Ajax\Maker\Haryana\_123.xlsx
#    Error: [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_123.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# 5. F:\Flipcarbon\Ajax\Maker\Haryana\_126.xlsx
#    Error: [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_126.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# 6. F:\Flipcarbon\Ajax\Maker\Haryana\_124.xlsx
#    Error: [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_124.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# 7. F:\Flipcarbon\Ajax\Maker\Haryana\_128.xlsx
#    Error: [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_128.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# 8. F:\Flipcarbon\Ajax\Maker\Haryana\_125.xlsx
#    Error: [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_125.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# 9. F:\Flipcarbon\Ajax\Maker\Haryana\_129.xlsx
#    Error: [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_129.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# 10. F:\Flipcarbon\Ajax\Maker\Haryana\_127.xlsx
#    Error: [WinError 183] Cannot create a file when that file already exists: 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\_127.xlsx' -> 'F:\\Flipcarbon\\Ajax\\Maker\\Haryana\\RTA_20250311225651.xlsx'
# ...and 12 more. See error_files_20250311_225702.csv for complete list.
#
# Total processing time: 17.06 seconds
# Log file: mass_excel_rename.log
