# %%
import pandas as pd
import re
import os
from datetime import datetime
import glob
import concurrent.futures
import time
import logging
import warnings
from openpyxl.styles import stylesheet

# Suppress openpyxl default style warning
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl.styles.stylesheet")

# Configure logging: set level to DEBUG for detailed logging (change to INFO in production)
logging.basicConfig(
    level=logging.DEBUG,  # DEBUG logs detailed info; change to INFO for less verbosity
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('vehicle_data_processing.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

def safe_int_conversion(val):
    """
    Safely convert a value to an integer.
    
    Attempts to convert the input to float then int.
    If conversion fails, returns 0.
    """
    try:
        return int(float(val))
    except (ValueError, TypeError) as e:
        logger.debug(f"Conversion error for value '{val}': {e}")
        return 0

def extract_metadata_from_title_and_filename(title, file_name):
    """
    Extract RTO name and state from the given title and file name.
    
    Uses multiple regular expression patterns to try to extract:
      - The RTO name (e.g., "NAMSAI - AR20")
      - The state (defaulting to "Arunachal Pradesh" if applicable)
    
    Parameters:
        title (str): The title extracted from the Excel file.
        file_name (str): The name of the Excel file.
    
    Returns:
        tuple: (rto_name, state_name)
    """
    # Remove file extension for filename-based extraction
    base_file_name = os.path.splitext(file_name)[0]
    
    # Option 1: Look for pattern "of <RTO>, <State> ("
    match = re.search(r'of\s+([\w-]+)\s*,\s*(.+?)\s*\(', title)
    if match:
        logger.debug("Option 1 metadata extraction succeeded.")
        return match.group(1), match.group(2)
    
    # Option 2: If "of" exists, attempt capturing "of <RTO - ARXX>"
    if "of" in title:
        match = re.search(r'of\s+([\w\s]+-\s*AR\d+)', title)
        if match:
            logger.debug("Option 2 metadata extraction succeeded.")
            return match.group(1).strip(), "Arunachal Pradesh"
    
    # Option 3: Look for pattern "<RTO> - <ARXX>" in the title
    match = re.search(r'([\w\s]+)\s*-\s*(AR\d+)', title)
    if match:
        logger.debug("Option 3 metadata extraction succeeded.")
        return f"{match.group(1).strip()} - {match.group(2)}", "Arunachal Pradesh"
    
    # Option 4: Look in the filename for pattern "<RTO> - <ARXX>"
    match = re.search(r'([\w\s]+)\s*-\s*(AR\d+)', base_file_name)
    if match:
        logger.debug("Option 4 metadata extraction succeeded.")
        return f"{match.group(1).strip()} - {match.group(2)}", "Arunachal Pradesh"
    
    # Option 5: Use underscore-separated file name parts
    parts = base_file_name.split('_')
    if len(parts) > 1 and parts[0] and len(parts[0]) > 3:
        if "arunachal" in parts[0].lower():
            state_name = "Arunachal Pradesh"
        else:
            state_name = parts[0].replace('_', ' ').strip()
        
        rto_match = re.search(r'(AR\d+)', parts[1] if len(parts) > 1 else '')
        if rto_match:
            logger.debug("Option 5 metadata extraction succeeded.")
            return f"RTO Code {rto_match.group(1)}", state_name
        else:
            # Option 6: Use specific keyword matching from the title
            rto_pattern = re.search(
                r'(ITANAGAR|TAWANG|BOMDILA|SEPPA|ZIRO|DAPORIJO|PASIGHAT|YINGKIONG|TEZU|NAMSAI|CHANGLANG|KHONSA|LONGDING|DOIMUKH|LIKABALI|AALO|PANGIN|YUPIA)',
                title
            )
            if rto_pattern:
                logger.debug("Option 6 metadata extraction succeeded.")
                return rto_pattern.group(1), "Arunachal Pradesh"
    
    # Final fallback: Check if "arunachal" appears in file name
    if "arunachal" in file_name.lower():
        logger.debug("Final fallback metadata extraction used.")
        return "Unknown RTO (Arunachal Pradesh)", "Arunachal Pradesh"
    
    logger.debug("Metadata extraction failed; returning defaults.")
    return "Unknown RTO", "Unknown State"

def process_vehicle_data_file(input_file_path, min_nonzero_rows=1):
    """
    Process a single Excel file and return a DataFrame of the processed data.
    
    Reads the Excel file, extracts metadata, identifies the header row,
    processes the data rows, and applies filtering based on non-zero values.
    
    Parameters:
        input_file_path (str): The full path to the Excel file.
        min_nonzero_rows (int): Minimum required non-zero rows for the file to be valid.
    
    Returns:
        pd.DataFrame or None: The processed data or None if processing fails.
    """
    try:
        file_name = os.path.basename(input_file_path)
        logger.info(f"Processing file: {file_name}")
        
        # Read the Excel file without a header row.
        try:
            df = pd.read_excel(input_file_path, header=None, engine='openpyxl')
            logger.debug(f"File '{file_name}' read successfully. Data shape: {df.shape}")
        except Exception as e:
            logger.error(f"Failed to read {file_name}: {e}")
            return None
        
        # Extract metadata (e.g., RTO name and state) from the first cell or fallback to file name.
        title = str(df.iloc[0, 0]) if len(df) > 0 and not pd.isna(df.iloc[0, 0]) else file_name
        rto_name, state_name = extract_metadata_from_title_and_filename(title, file_name)
        logger.info(f"Extracted metadata for '{file_name}': RTO='{rto_name}', State='{state_name}'")
        
        # Identify the header row by scanning the first 15 rows for JAN and FEB columns.
        header_row = None
        for i in range(min(15, len(df))):
            row_data = df.iloc[i].astype(str).str.upper()
            if (('JAN' in row_data.values and 'FEB' in row_data.values) or
                ('JANUARY' in row_data.values and 'FEBRUARY' in row_data.values)):
                header_row = i
                break
        if header_row is None:
            logger.warning(f"Header row with JAN and FEB not found in '{file_name}'.")
            return None
        
        logger.debug(f"Header row detected at row {header_row} in '{file_name}': {df.iloc[header_row].tolist()}")
        
        # Determine column indices for JAN, FEB, and Vehicle Class
        headers = df.iloc[header_row].astype(str).str.upper()
        jan_col = feb_col = vehicle_class_col = None
        for i, val in enumerate(headers):
            if pd.isna(val):
                continue
            if val in ('JAN', 'JANUARY'):
                jan_col = i
            elif val in ('FEB', 'FEBRUARY'):
                feb_col = i
            elif 'VEHICLE CLASS' in val or ('VEHICLE' in val and 'CLASS' in val):
                vehicle_class_col = i
        
        # Fallback for vehicle class column: default to index 1 if not found.
        if vehicle_class_col is None:
            vehicle_class_col = 1
            vehicle_keywords = ['VEHICLE', 'CLASS', 'CAR', 'BUS', 'TRUCK', 'AUTO']
            for i, val in enumerate(headers):
                if isinstance(val, str) and any(keyword in val for keyword in vehicle_keywords):
                    vehicle_class_col = i
                    break
        
        if jan_col is None or feb_col is None or vehicle_class_col is None:
            logger.warning(f"Missing critical columns in '{file_name}'. Found - Vehicle Class: {vehicle_class_col}, Jan: {jan_col}, Feb: {feb_col}")
            return None
        
        # Process data rows (starting from the row after the header)
        data = []
        data_start_row = header_row + 1
        for i in range(data_start_row, len(df)):
            if vehicle_class_col >= len(df.columns) or pd.isna(df.iloc[i, vehicle_class_col]) or df.iloc[i].isna().all():
                continue
            
            try:
                vehicle_class = str(df.iloc[i, vehicle_class_col]).strip()
                if not vehicle_class:
                    continue
                
                raw_jan = df.iloc[i, jan_col] if jan_col < len(df.columns) else None
                raw_feb = df.iloc[i, feb_col] if feb_col < len(df.columns) else None
                logger.debug(f"File '{file_name}' - Row {i}: Raw JAN = {raw_jan}, Raw FEB = {raw_feb}")
                
                jan_value = safe_int_conversion(raw_jan)
                feb_value = safe_int_conversion(raw_feb)
                
                data.append({
                    'State': state_name,
                    'RTO Name': rto_name,
                    'Vehicle Class': vehicle_class,
                    'Jan': jan_value,
                    'Feb': feb_value
                })
            except Exception as row_error:
                logger.error(f"Error processing row {i} in '{file_name}': {row_error}")
                continue
        
        if not data:
            logger.warning(f"No valid data extracted from '{file_name}'.")
            return None
        
        # Optionally filter out rows where both Jan and Feb are zero
        if min_nonzero_rows > 0:
            nonzero_data = [row for row in data if row['Jan'] > 0 or row['Feb'] > 0]
            if len(nonzero_data) < min_nonzero_rows:
                logger.info(f"Skipping '{file_name}' - only {len(nonzero_data)} non-zero rows found (minimum required: {min_nonzero_rows}).")
                return None
            data = nonzero_data
        
        result_df = pd.DataFrame(data)
        logger.info(f"File '{file_name}' processed successfully with {len(result_df)} rows.")
        return result_df
    
    except Exception as e:
        logger.error(f"Unexpected error processing '{os.path.basename(input_file_path)}': {e}")
        return None

def batch_process_files(input_folder, output_folder, file_pattern="*.xlsx", max_workers=4, min_nonzero_rows=1):
    """
    Process all Excel files in the specified folder and save a single combined output Excel file.
    
    Parameters:
        input_folder (str): Directory containing the input Excel files.
        output_folder (str): Directory to save the combined output file.
        file_pattern (str): Pattern for matching Excel files.
        max_workers (int): Maximum number of parallel threads.
        min_nonzero_rows (int): Minimum required non-zero rows for a file to be considered valid.
    """
    try:
        os.makedirs(output_folder, exist_ok=True)
        logger.debug(f"Output folder '{output_folder}' is ready.")
    except Exception as e:
        logger.error(f"Failed to create output folder '{output_folder}': {e}")
        return
    
    file_paths = glob.glob(os.path.join(input_folder, file_pattern))
    total_files = len(file_paths)
    
    if total_files == 0:
        logger.warning(f"No files matching '{file_pattern}' found in '{input_folder}'.")
        return
    
    logger.info(f"Found {total_files} files to process in '{input_folder}'.")
    
    all_results = []
    processed_count = 0
    error_count = 0
    start_time = time.time()
    
    # Process files in parallel using ThreadPoolExecutor
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_file = {
            executor.submit(process_vehicle_data_file, file_path, min_nonzero_rows): file_path 
            for file_path in file_paths
        }
        for future in concurrent.futures.as_completed(future_to_file):
            file_path = future_to_file[future]
            try:
                result_df = future.result()
                if result_df is not None:
                    all_results.append(result_df)
                    processed_count += 1
                else:
                    error_count += 1
            except Exception as e:
                logger.error(f"Error processing '{os.path.basename(file_path)}': {e}")
                error_count += 1
    
    if all_results:
        try:
            combined_df = pd.concat(all_results, ignore_index=True)
        except Exception as e:
            logger.error(f"Error concatenating data frames: {e}")
            return
        
        # Create the output file name using today's date in DD-MM-YYYY format.
        today_str = datetime.now().strftime("%d-%m-%Y")
        combined_output = os.path.join(output_folder, f"Consolidated Maker Wise Data ({today_str}).xlsx")
        try:
            combined_df.to_excel(combined_output, index=False)
            logger.info(f"Combined output successfully saved to '{combined_output}'.")
        except Exception as e:
            logger.error(f"Failed to save combined output: {e}")
            return
        
        end_time = time.time()
        duration = end_time - start_time
        
        logger.info("Processing Summary:")
        logger.info(f"  Total files processed: {total_files}")
        logger.info(f"  Successfully processed: {processed_count}")
        logger.info(f"  Files with errors/skipped: {error_count}")
        logger.info(f"  Total records combined: {len(combined_df)}")
        logger.info(f"  Total processing time: {duration:.2f} seconds")
        
        nonzero_records = combined_df[(combined_df['Jan'] > 0) | (combined_df['Feb'] > 0)]
        logger.info(f"  Records with non-zero values: {len(nonzero_records)}")
        logger.info("  Top 5 vehicle classes by count:")
        logger.info(combined_df['Vehicle Class'].value_counts().head(5).to_string())
        
        if 'State' in combined_df.columns:
            logger.info("  Records by state:")
            logger.info(combined_df['State'].value_counts().to_string())
    else:
        logger.warning("No valid data was processed from any files.")

if __name__ == "__main__":
    # User-friendly start message
    print("Starting the Vehicle Data Processing script...")
    logger.info("Vehicle Data Processing Script started.")
    
    # Set your input and output folders (update these paths as needed)
    input_folder = r"C:\Users\ASUS\OneDrive\Documents\Maker Wise\Arunachal Pradesh"
    output_folder = r"C:\Users\ASUS\OneDrive\Desktop"
    
    # Configuration parameters
    file_pattern = "*.xlsx"     # Process all Excel files in the input folder
    max_workers = 4             # Number of parallel threads
    min_nonzero_rows = 2        # Minimum non-zero rows required for a file to be processed
    
    try:
        batch_process_files(input_folder, output_folder, file_pattern, max_workers, min_nonzero_rows)
        logger.info("Vehicle Data Processing completed successfully.")
        print("Processing completed successfully. Check the output folder and log file for details.")
    except Exception as e:
        logger.error(f"An unexpected error occurred: {e}")
        print(f"An error occurred during processing: {e}")
# Out:
# 2025-02-17 13:12:19,546 - INFO - Vehicle Data Processing Script started.
# 2025-02-17 13:12:19,547 - DEBUG - Output folder 'C:\Users\ASUS\OneDrive\Desktop' is ready.
# 2025-02-17 13:12:19,548 - INFO - Found 28 files to process in 'C:\Users\ASUS\OneDrive\Documents\Maker Wise\Arunachal Pradesh'.
# 2025-02-17 13:12:19,550 - INFO - Processing file: ANJAW - AR17.xlsx
# 2025-02-17 13:12:19,554 - INFO - Processing file: _1.xlsx
# 2025-02-17 13:12:19,557 - INFO - Processing file: _10.xlsx
# 2025-02-17 13:12:19,559 - INFO - Processing file: _11.xlsx
# 2025-02-17 13:12:19,572 - DEBUG - File 'ANJAW - AR17.xlsx' read successfully. Data shape: (6, 5)
# 2025-02-17 13:12:19,575 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,577 - INFO - Extracted metadata for 'ANJAW - AR17.xlsx': RTO='ANJAW - AR17', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,580 - DEBUG - Header row detected at row 3 in 'ANJAW - AR17.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,582 - DEBUG - File '_1.xlsx' read successfully. Data shape: (9, 5)
# 2025-02-17 13:12:19,586 - DEBUG - File 'ANJAW - AR17.xlsx' - Row 4: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,588 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,590 - DEBUG - File '_10.xlsx' read successfully. Data shape: (9, 5)
# 2025-02-17 13:12:19,592 - DEBUG - File 'ANJAW - AR17.xlsx' - Row 5: Raw JAN = 4, Raw FEB = 1
# 2025-02-17 13:12:19,597 - INFO - Extracted metadata for '_1.xlsx': RTO='CHANGLANG - AR12', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,598 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,601 - DEBUG - File '_11.xlsx' read successfully. Data shape: (12, 5)
# 2025-02-17 13:12:19,602 - INFO - File 'ANJAW - AR17.xlsx' processed successfully with 2 rows.
# 2025-02-17 13:12:19,603 - DEBUG - Header row detected at row 3 in '_1.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,604 - INFO - Extracted metadata for '_10.xlsx': RTO='LEPARADA - AR25', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,606 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,607 - INFO - Processing file: _12.xlsx
# 2025-02-17 13:12:19,608 - DEBUG - File '_1.xlsx' - Row 4: Raw JAN = 3, Raw FEB = 0
# 2025-02-17 13:12:19,610 - DEBUG - Header row detected at row 3 in '_10.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,610 - INFO - Extracted metadata for '_11.xlsx': RTO='LOHIT - AR11', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,612 - DEBUG - File '_1.xlsx' - Row 5: Raw JAN = 3, Raw FEB = 3
# 2025-02-17 13:12:19,613 - DEBUG - File '_10.xlsx' - Row 4: Raw JAN = 2, Raw FEB = 1
# 2025-02-17 13:12:19,616 - DEBUG - Header row detected at row 3 in '_11.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,618 - DEBUG - File '_12.xlsx' read successfully. Data shape: (13, 5)
# 2025-02-17 13:12:19,619 - DEBUG - File '_1.xlsx' - Row 6: Raw JAN = 16, Raw FEB = 9
# 2025-02-17 13:12:19,619 - DEBUG - File '_10.xlsx' - Row 5: Raw JAN = 2, Raw FEB = 0
# 2025-02-17 13:12:19,620 - DEBUG - File '_11.xlsx' - Row 4: Raw JAN = 88, Raw FEB = 16
# 2025-02-17 13:12:19,621 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,621 - DEBUG - File '_1.xlsx' - Row 7: Raw JAN = 45, Raw FEB = 19
# 2025-02-17 13:12:19,623 - DEBUG - File '_10.xlsx' - Row 6: Raw JAN = 17, Raw FEB = 1
# 2025-02-17 13:12:19,624 - DEBUG - File '_11.xlsx' - Row 5: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,624 - INFO - Extracted metadata for '_12.xlsx': RTO='LONGDING - AR18', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,625 - DEBUG - File '_1.xlsx' - Row 8: Raw JAN = 1, Raw FEB = 0
# 2025-02-17 13:12:19,625 - DEBUG - File '_10.xlsx' - Row 7: Raw JAN = 8, Raw FEB = 3
# 2025-02-17 13:12:19,626 - DEBUG - File '_11.xlsx' - Row 6: Raw JAN = 4, Raw FEB = 3
# 2025-02-17 13:12:19,627 - DEBUG - Header row detected at row 3 in '_12.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,627 - INFO - File '_1.xlsx' processed successfully with 5 rows.
# 2025-02-17 13:12:19,628 - DEBUG - File '_10.xlsx' - Row 8: Raw JAN = 1, Raw FEB = 0
# 2025-02-17 13:12:19,629 - DEBUG - File '_11.xlsx' - Row 7: Raw JAN = 6, Raw FEB = 1
# 2025-02-17 13:12:19,629 - DEBUG - File '_12.xlsx' - Row 4: Raw JAN = 2, Raw FEB = 0
# 2025-02-17 13:12:19,630 - INFO - Processing file: _13.xlsx
# 2025-02-17 13:12:19,630 - INFO - File '_10.xlsx' processed successfully with 5 rows.
# 2025-02-17 13:12:19,631 - DEBUG - File '_11.xlsx' - Row 8: Raw JAN = 7, Raw FEB = 6
# 2025-02-17 13:12:19,631 - DEBUG - File '_12.xlsx' - Row 5: Raw JAN = 7, Raw FEB = 2
# 2025-02-17 13:12:19,632 - INFO - Processing file: _14.xlsx
# 2025-02-17 13:12:19,633 - DEBUG - File '_11.xlsx' - Row 9: Raw JAN = 108, Raw FEB = 49
# 2025-02-17 13:12:19,634 - DEBUG - File '_12.xlsx' - Row 6: Raw JAN = 1, Raw FEB = 0
# 2025-02-17 13:12:19,638 - DEBUG - File '_13.xlsx' read successfully. Data shape: (16, 5)
# 2025-02-17 13:12:19,639 - DEBUG - File '_11.xlsx' - Row 10: Raw JAN = 45, Raw FEB = 17
# 2025-02-17 13:12:19,640 - DEBUG - File '_12.xlsx' - Row 7: Raw JAN = 2, Raw FEB = 1
# 2025-02-17 13:12:19,641 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,645 - DEBUG - File '_11.xlsx' - Row 11: Raw JAN = 6, Raw FEB = 1
# 2025-02-17 13:12:19,646 - DEBUG - File '_14.xlsx' read successfully. Data shape: (12, 5)
# 2025-02-17 13:12:19,647 - DEBUG - File '_12.xlsx' - Row 8: Raw JAN = 1, Raw FEB = 0
# 2025-02-17 13:12:19,647 - INFO - Extracted metadata for '_13.xlsx': RTO='LOWER DIBANG VALLEY - AR16', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,648 - INFO - File '_11.xlsx' processed successfully with 8 rows.
# 2025-02-17 13:12:19,648 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,649 - DEBUG - File '_12.xlsx' - Row 9: Raw JAN = 5, Raw FEB = 3
# 2025-02-17 13:12:19,650 - DEBUG - Header row detected at row 3 in '_13.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,650 - INFO - Processing file: _15.xlsx
# 2025-02-17 13:12:19,651 - INFO - Extracted metadata for '_14.xlsx': RTO='LOWER SIANG - AR22', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,651 - DEBUG - File '_12.xlsx' - Row 10: Raw JAN = 12, Raw FEB = 11
# 2025-02-17 13:12:19,653 - DEBUG - File '_13.xlsx' - Row 4: Raw JAN = 2, Raw FEB = 3
# 2025-02-17 13:12:19,656 - DEBUG - Header row detected at row 3 in '_14.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,657 - DEBUG - File '_12.xlsx' - Row 11: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,660 - DEBUG - File '_13.xlsx' - Row 5: Raw JAN = 1, Raw FEB = 0
# 2025-02-17 13:12:19,662 - DEBUG - File '_14.xlsx' - Row 4: Raw JAN = 11, Raw FEB = 0
# 2025-02-17 13:12:19,663 - DEBUG - File '_15.xlsx' read successfully. Data shape: (11, 5)
# 2025-02-17 13:12:19,664 - DEBUG - File '_12.xlsx' - Row 12: Raw JAN = 0, Raw FEB = 2
# 2025-02-17 13:12:19,665 - DEBUG - File '_13.xlsx' - Row 6: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,666 - DEBUG - File '_14.xlsx' - Row 5: Raw JAN = 6, Raw FEB = 9
# 2025-02-17 13:12:19,666 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,667 - INFO - File '_12.xlsx' processed successfully with 9 rows.
# 2025-02-17 13:12:19,668 - DEBUG - File '_13.xlsx' - Row 7: Raw JAN = 2, Raw FEB = 0
# 2025-02-17 13:12:19,668 - DEBUG - File '_14.xlsx' - Row 6: Raw JAN = 16, Raw FEB = 6
# 2025-02-17 13:12:19,669 - INFO - Extracted metadata for '_15.xlsx': RTO='LOWER SUBANSIRI - AR6', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,669 - INFO - Processing file: _16.xlsx
# 2025-02-17 13:12:19,670 - DEBUG - File '_13.xlsx' - Row 8: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,671 - DEBUG - File '_14.xlsx' - Row 7: Raw JAN = 1, Raw FEB = 0
# 2025-02-17 13:12:19,672 - DEBUG - Header row detected at row 3 in '_15.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,674 - DEBUG - File '_13.xlsx' - Row 9: Raw JAN = 3, Raw FEB = 6
# 2025-02-17 13:12:19,676 - DEBUG - File '_14.xlsx' - Row 8: Raw JAN = 86, Raw FEB = 95
# 2025-02-17 13:12:19,678 - DEBUG - File '_15.xlsx' - Row 4: Raw JAN = 3, Raw FEB = 0
# 2025-02-17 13:12:19,679 - DEBUG - File '_13.xlsx' - Row 10: Raw JAN = 36, Raw FEB = 63
# 2025-02-17 13:12:19,682 - DEBUG - File '_16.xlsx' read successfully. Data shape: (14, 5)
# 2025-02-17 13:12:19,683 - DEBUG - File '_14.xlsx' - Row 9: Raw JAN = 4, Raw FEB = 0
# 2025-02-17 13:12:19,683 - DEBUG - File '_15.xlsx' - Row 5: Raw JAN = 3, Raw FEB = 0
# 2025-02-17 13:12:19,684 - DEBUG - File '_13.xlsx' - Row 11: Raw JAN = 4, Raw FEB = 0
# 2025-02-17 13:12:19,684 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,685 - DEBUG - File '_14.xlsx' - Row 10: Raw JAN = 34, Raw FEB = 14
# 2025-02-17 13:12:19,686 - DEBUG - File '_15.xlsx' - Row 6: Raw JAN = 2, Raw FEB = 1
# 2025-02-17 13:12:19,686 - DEBUG - File '_13.xlsx' - Row 12: Raw JAN = 35, Raw FEB = 41
# 2025-02-17 13:12:19,687 - INFO - Extracted metadata for '_16.xlsx': RTO='NAMSAI - AR20', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,688 - DEBUG - File '_14.xlsx' - Row 11: Raw JAN = 4, Raw FEB = 4
# 2025-02-17 13:12:19,689 - DEBUG - File '_15.xlsx' - Row 7: Raw JAN = 6, Raw FEB = 0
# 2025-02-17 13:12:19,690 - DEBUG - File '_13.xlsx' - Row 13: Raw JAN = 1, Raw FEB = 0
# 2025-02-17 13:12:19,691 - DEBUG - Header row detected at row 3 in '_16.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,692 - INFO - File '_14.xlsx' processed successfully with 8 rows.
# 2025-02-17 13:12:19,693 - DEBUG - File '_15.xlsx' - Row 8: Raw JAN = 13, Raw FEB = 2
# 2025-02-17 13:12:19,694 - DEBUG - File '_13.xlsx' - Row 14: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,695 - DEBUG - File '_16.xlsx' - Row 4: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,695 - INFO - Processing file: _17.xlsx
# 2025-02-17 13:12:19,696 - DEBUG - File '_15.xlsx' - Row 9: Raw JAN = 17, Raw FEB = 3
# 2025-02-17 13:12:19,696 - DEBUG - File '_13.xlsx' - Row 15: Raw JAN = 1, Raw FEB = 4
# 2025-02-17 13:12:19,697 - DEBUG - File '_16.xlsx' - Row 5: Raw JAN = 11, Raw FEB = 4
# 2025-02-17 13:12:19,698 - DEBUG - File '_15.xlsx' - Row 10: Raw JAN = 1, Raw FEB = 0
# 2025-02-17 13:12:19,699 - INFO - File '_13.xlsx' processed successfully with 12 rows.
# 2025-02-17 13:12:19,699 - DEBUG - File '_16.xlsx' - Row 6: Raw JAN = 2, Raw FEB = 2
# 2025-02-17 13:12:19,700 - INFO - File '_15.xlsx' processed successfully with 7 rows.
# 2025-02-17 13:12:19,701 - INFO - Processing file: _18.xlsx
# 2025-02-17 13:12:19,702 - DEBUG - File '_16.xlsx' - Row 7: Raw JAN = 2, Raw FEB = 0
# 2025-02-17 13:12:19,702 - INFO - Processing file: _19.xlsx
# 2025-02-17 13:12:19,706 - DEBUG - File '_16.xlsx' - Row 8: Raw JAN = 22, Raw FEB = 8
# 2025-02-17 13:12:19,708 - DEBUG - File '_17.xlsx' read successfully. Data shape: (7, 5)
# 2025-02-17 13:12:19,709 - DEBUG - File '_16.xlsx' - Row 9: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,710 - DEBUG - Option 3 metadata extraction succeeded.
# 2025-02-17 13:12:19,711 - DEBUG - File '_16.xlsx' - Row 10: Raw JAN = 133, Raw FEB = 79
# 2025-02-17 13:12:19,712 - INFO - Extracted metadata for '_17.xlsx': RTO='KESANG - AR24', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,714 - DEBUG - File '_16.xlsx' - Row 11: Raw JAN = 122, Raw FEB = 39
# 2025-02-17 13:12:19,716 - DEBUG - Header row detected at row 3 in '_17.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,717 - DEBUG - File '_18.xlsx' read successfully. Data shape: (7, 5)
# 2025-02-17 13:12:19,718 - DEBUG - File '_16.xlsx' - Row 12: Raw JAN = 2, Raw FEB = 2
# 2025-02-17 13:12:19,720 - DEBUG - File '_17.xlsx' - Row 4: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,721 - DEBUG - Option 3 metadata extraction succeeded.
# 2025-02-17 13:12:19,723 - DEBUG - File '_16.xlsx' - Row 13: Raw JAN = 17, Raw FEB = 9
# 2025-02-17 13:12:19,724 - DEBUG - File '_17.xlsx' - Row 5: Raw JAN = 2, Raw FEB = 0
# 2025-02-17 13:12:19,726 - DEBUG - File '_19.xlsx' read successfully. Data shape: (8, 5)
# 2025-02-17 13:12:19,726 - INFO - Extracted metadata for '_18.xlsx': RTO='YOMI - AR26', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,727 - INFO - File '_16.xlsx' processed successfully with 10 rows.
# 2025-02-17 13:12:19,728 - DEBUG - File '_17.xlsx' - Row 6: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,728 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,730 - INFO - Extracted metadata for '_19.xlsx': RTO='SIANG - AR21', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,729 - INFO - Processing file: _2.xlsx
# 2025-02-17 13:12:19,730 - INFO - File '_17.xlsx' processed successfully with 3 rows.
# 2025-02-17 13:12:19,729 - DEBUG - Header row detected at row 3 in '_18.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,731 - DEBUG - Header row detected at row 3 in '_19.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,732 - INFO - Processing file: _20.xlsx
# 2025-02-17 13:12:19,733 - DEBUG - File '_18.xlsx' - Row 4: Raw JAN = 1, Raw FEB = 0
# 2025-02-17 13:12:19,736 - DEBUG - File '_19.xlsx' - Row 4: Raw JAN = 3, Raw FEB = 1
# 2025-02-17 13:12:19,740 - DEBUG - File '_2.xlsx' read successfully. Data shape: (7, 5)
# 2025-02-17 13:12:19,741 - DEBUG - File '_18.xlsx' - Row 5: Raw JAN = 2, Raw FEB = 0
# Starting the Vehicle Data Processing script...
# 2025-02-17 13:12:19,742 - DEBUG - File '_19.xlsx' - Row 5: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,742 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,747 - DEBUG - File '_20.xlsx' read successfully. Data shape: (4, 5)
# 2025-02-17 13:12:19,748 - DEBUG - File '_18.xlsx' - Row 6: Raw JAN = 4, Raw FEB = 0
# 2025-02-17 13:12:19,748 - DEBUG - File '_19.xlsx' - Row 6: Raw JAN = 8, Raw FEB = 5
# 2025-02-17 13:12:19,749 - INFO - Extracted metadata for '_2.xlsx': RTO='DIBANG VALLEY - AR10', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,749 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,750 - INFO - File '_18.xlsx' processed successfully with 3 rows.
# 2025-02-17 13:12:19,751 - DEBUG - File '_19.xlsx' - Row 7: Raw JAN = 1, Raw FEB = 0
# 2025-02-17 13:12:19,752 - DEBUG - Header row detected at row 3 in '_2.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,752 - INFO - Extracted metadata for '_20.xlsx': RTO='STATE TRANSPORT AUTHORITY - AR99', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,752 - INFO - Processing file: _21.xlsx
# 2025-02-17 13:12:19,753 - INFO - File '_19.xlsx' processed successfully with 4 rows.
# 2025-02-17 13:12:19,754 - DEBUG - File '_2.xlsx' - Row 4: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,755 - DEBUG - Header row detected at row 3 in '_20.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,758 - INFO - Processing file: _22.xlsx
# 2025-02-17 13:12:19,759 - DEBUG - File '_2.xlsx' - Row 5: Raw JAN = 1, Raw FEB = 0
# 2025-02-17 13:12:19,761 - WARNING - No valid data extracted from '_20.xlsx'.
# 2025-02-17 13:12:19,770 - INFO - Processing file: _23.xlsx
# 2025-02-17 13:12:19,766 - DEBUG - File '_21.xlsx' read successfully. Data shape: (10, 5)
# 2025-02-17 13:12:19,765 - DEBUG - File '_2.xlsx' - Row 6: Raw JAN = 4, Raw FEB = 1
# 2025-02-17 13:12:19,783 - DEBUG - File '_22.xlsx' read successfully. Data shape: (10, 5)
# 2025-02-17 13:12:19,784 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,788 - INFO - File '_2.xlsx' processed successfully with 3 rows.
# 2025-02-17 13:12:19,796 - DEBUG - File '_23.xlsx' read successfully. Data shape: (7, 5)
# 2025-02-17 13:12:19,796 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,798 - INFO - Extracted metadata for '_21.xlsx': RTO='TAWANG - AR3', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,799 - INFO - Processing file: _24.xlsx
# 2025-02-17 13:12:19,800 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,801 - INFO - Extracted metadata for '_22.xlsx': RTO='TIRAP - AR13', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,802 - DEBUG - Header row detected at row 3 in '_21.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,804 - INFO - Extracted metadata for '_23.xlsx': RTO='UPPER SIANG - AR14', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,806 - DEBUG - Header row detected at row 3 in '_22.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,815 - DEBUG - File '_21.xlsx' - Row 4: Raw JAN = 0, Raw FEB = 2
# 2025-02-17 13:12:19,816 - DEBUG - File '_24.xlsx' read successfully. Data shape: (6, 5)
# 2025-02-17 13:12:19,819 - DEBUG - Header row detected at row 3 in '_23.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,820 - DEBUG - File '_22.xlsx' - Row 4: Raw JAN = 1, Raw FEB = 0
# 2025-02-17 13:12:19,820 - DEBUG - File '_21.xlsx' - Row 5: Raw JAN = 1, Raw FEB = 5
# 2025-02-17 13:12:19,821 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,823 - DEBUG - File '_23.xlsx' - Row 4: Raw JAN = 16, Raw FEB = 5
# 2025-02-17 13:12:19,824 - DEBUG - File '_22.xlsx' - Row 5: Raw JAN = 2, Raw FEB = 1
# 2025-02-17 13:12:19,825 - DEBUG - File '_21.xlsx' - Row 6: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,826 - INFO - Extracted metadata for '_24.xlsx': RTO='UPPER SUBANSIRI - AR7', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,827 - DEBUG - File '_23.xlsx' - Row 5: Raw JAN = 5, Raw FEB = 4
# 2025-02-17 13:12:19,828 - DEBUG - File '_22.xlsx' - Row 6: Raw JAN = 4, Raw FEB = 1
# 2025-02-17 13:12:19,829 - DEBUG - File '_21.xlsx' - Row 7: Raw JAN = 1, Raw FEB = 5
# 2025-02-17 13:12:19,831 - DEBUG - Header row detected at row 3 in '_24.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,831 - DEBUG - File '_23.xlsx' - Row 6: Raw JAN = 1, Raw FEB = 1
# 2025-02-17 13:12:19,832 - DEBUG - File '_22.xlsx' - Row 7: Raw JAN = 1, Raw FEB = 0
# 2025-02-17 13:12:19,833 - DEBUG - File '_21.xlsx' - Row 8: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,834 - DEBUG - File '_24.xlsx' - Row 4: Raw JAN = 26, Raw FEB = 21
# 2025-02-17 13:12:19,834 - INFO - File '_23.xlsx' processed successfully with 3 rows.
# 2025-02-17 13:12:19,835 - DEBUG - File '_22.xlsx' - Row 8: Raw JAN = 24, Raw FEB = 15
# 2025-02-17 13:12:19,837 - DEBUG - File '_21.xlsx' - Row 9: Raw JAN = 8, Raw FEB = 21
# 2025-02-17 13:12:19,838 - DEBUG - File '_24.xlsx' - Row 5: Raw JAN = 0, Raw FEB = 2
# 2025-02-17 13:12:19,838 - INFO - Processing file: _25.xlsx
# 2025-02-17 13:12:19,839 - DEBUG - File '_22.xlsx' - Row 9: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,840 - INFO - File '_21.xlsx' processed successfully with 6 rows.
# 2025-02-17 13:12:19,842 - INFO - File '_24.xlsx' processed successfully with 2 rows.
# 2025-02-17 13:12:19,844 - INFO - File '_22.xlsx' processed successfully with 6 rows.
# 2025-02-17 13:12:19,845 - INFO - Processing file: _26.xlsx
# 2025-02-17 13:12:19,846 - INFO - Processing file: _27.xlsx
# 2025-02-17 13:12:19,849 - INFO - Processing file: _3.xlsx
# 2025-02-17 13:12:19,852 - DEBUG - File '_25.xlsx' read successfully. Data shape: (9, 5)
# 2025-02-17 13:12:19,855 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,855 - INFO - Extracted metadata for '_25.xlsx': RTO='WEST KAMENG - AR4', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,858 - DEBUG - Header row detected at row 3 in '_25.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,859 - DEBUG - File '_25.xlsx' - Row 4: Raw JAN = 0, Raw FEB = 2
# 2025-02-17 13:12:19,862 - DEBUG - File '_25.xlsx' - Row 5: Raw JAN = 5, Raw FEB = 1
# 2025-02-17 13:12:19,864 - DEBUG - File '_25.xlsx' - Row 6: Raw JAN = 2, Raw FEB = 3
# 2025-02-17 13:12:19,866 - DEBUG - File '_25.xlsx' - Row 7: Raw JAN = 26, Raw FEB = 7
# 2025-02-17 13:12:19,866 - DEBUG - File '_26.xlsx' read successfully. Data shape: (9, 5)
# 2025-02-17 13:12:19,867 - DEBUG - File '_25.xlsx' - Row 8: Raw JAN = 52, Raw FEB = 16
# 2025-02-17 13:12:19,868 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,869 - INFO - File '_25.xlsx' processed successfully with 5 rows.
# 2025-02-17 13:12:19,870 - INFO - Extracted metadata for '_26.xlsx': RTO='WEST SIANG - AR8', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,872 - INFO - Processing file: _4.xlsx
# 2025-02-17 13:12:19,875 - DEBUG - Header row detected at row 3 in '_26.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,878 - DEBUG - File '_27.xlsx' read successfully. Data shape: (11, 5)
# 2025-02-17 13:12:19,879 - DEBUG - File '_26.xlsx' - Row 4: Raw JAN = 1, Raw FEB = 0
# 2025-02-17 13:12:19,880 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,882 - DEBUG - File '_26.xlsx' - Row 5: Raw JAN = 3, Raw FEB = 0
# 2025-02-17 13:12:19,884 - INFO - Extracted metadata for '_27.xlsx': RTO='YUPIA - AR2', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,885 - DEBUG - File '_3.xlsx' read successfully. Data shape: (8, 5)
# 2025-02-17 13:12:19,886 - DEBUG - File '_26.xlsx' - Row 6: Raw JAN = 60, Raw FEB = 25
# 2025-02-17 13:12:19,887 - DEBUG - Header row detected at row 3 in '_27.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,889 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,892 - DEBUG - File '_4.xlsx' read successfully. Data shape: (14, 5)
# 2025-02-17 13:12:19,892 - DEBUG - File '_26.xlsx' - Row 7: Raw JAN = 49, Raw FEB = 25
# 2025-02-17 13:12:19,893 - DEBUG - File '_27.xlsx' - Row 4: Raw JAN = 5, Raw FEB = 4
# 2025-02-17 13:12:19,894 - INFO - Extracted metadata for '_3.xlsx': RTO='EAST KAMENG - AR5', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,894 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,894 - DEBUG - File '_26.xlsx' - Row 8: Raw JAN = 2, Raw FEB = 0
# 2025-02-17 13:12:19,895 - DEBUG - File '_27.xlsx' - Row 5: Raw JAN = 3, Raw FEB = 1
# 2025-02-17 13:12:19,896 - DEBUG - Header row detected at row 3 in '_3.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,896 - INFO - Extracted metadata for '_4.xlsx': RTO='EAST SIANG - AR9', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,897 - INFO - File '_26.xlsx' processed successfully with 5 rows.
# 2025-02-17 13:12:19,898 - DEBUG - File '_27.xlsx' - Row 6: Raw JAN = 2, Raw FEB = 1
# 2025-02-17 13:12:19,898 - DEBUG - File '_3.xlsx' - Row 4: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,899 - DEBUG - Header row detected at row 3 in '_4.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,900 - INFO - Processing file: _5.xlsx
# 2025-02-17 13:12:19,900 - DEBUG - File '_27.xlsx' - Row 7: Raw JAN = 34, Raw FEB = 16
# 2025-02-17 13:12:19,901 - DEBUG - File '_3.xlsx' - Row 5: Raw JAN = 2, Raw FEB = 2
# 2025-02-17 13:12:19,901 - DEBUG - File '_4.xlsx' - Row 4: Raw JAN = 1, Raw FEB = 0
# 2025-02-17 13:12:19,903 - DEBUG - File '_27.xlsx' - Row 8: Raw JAN = 63, Raw FEB = 26
# 2025-02-17 13:12:19,903 - DEBUG - File '_3.xlsx' - Row 6: Raw JAN = 26, Raw FEB = 0
# 2025-02-17 13:12:19,905 - DEBUG - File '_4.xlsx' - Row 5: Raw JAN = 2, Raw FEB = 1
# 2025-02-17 13:12:19,906 - DEBUG - File '_27.xlsx' - Row 9: Raw JAN = 2, Raw FEB = 4
# 2025-02-17 13:12:19,907 - DEBUG - File '_3.xlsx' - Row 7: Raw JAN = 9, Raw FEB = 2
# 2025-02-17 13:12:19,908 - DEBUG - File '_4.xlsx' - Row 6: Raw JAN = 1, Raw FEB = 0
# 2025-02-17 13:12:19,911 - DEBUG - File '_27.xlsx' - Row 10: Raw JAN = 1, Raw FEB = 0
# 2025-02-17 13:12:19,914 - DEBUG - File '_5.xlsx' read successfully. Data shape: (20, 5)
# 2025-02-17 13:12:19,915 - INFO - File '_3.xlsx' processed successfully with 4 rows.
# 2025-02-17 13:12:19,916 - DEBUG - File '_4.xlsx' - Row 7: Raw JAN = 2, Raw FEB = 0
# 2025-02-17 13:12:19,916 - INFO - File '_27.xlsx' processed successfully with 7 rows.
# 2025-02-17 13:12:19,917 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,917 - INFO - Processing file: _6.xlsx
# 2025-02-17 13:12:19,918 - DEBUG - File '_4.xlsx' - Row 8: Raw JAN = 15, Raw FEB = 4
# 2025-02-17 13:12:19,918 - INFO - Processing file: _7.xlsx
# 2025-02-17 13:12:19,919 - INFO - Extracted metadata for '_5.xlsx': RTO='ITANAGAR CAPITAL REGION - AR1', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,920 - DEBUG - File '_4.xlsx' - Row 9: Raw JAN = 176, Raw FEB = 58
# 2025-02-17 13:12:19,922 - DEBUG - Header row detected at row 3 in '_5.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,923 - DEBUG - File '_4.xlsx' - Row 10: Raw JAN = 113, Raw FEB = 52
# 2025-02-17 13:12:19,924 - DEBUG - File '_5.xlsx' - Row 4: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,925 - DEBUG - File '_4.xlsx' - Row 11: Raw JAN = 0, Raw FEB = 2
# 2025-02-17 13:12:19,926 - DEBUG - File '_5.xlsx' - Row 5: Raw JAN = 36, Raw FEB = 25
# 2025-02-17 13:12:19,928 - DEBUG - File '_4.xlsx' - Row 12: Raw JAN = 4, Raw FEB = 1
# 2025-02-17 13:12:19,929 - DEBUG - File '_5.xlsx' - Row 6: Raw JAN = 2, Raw FEB = 0
# 2025-02-17 13:12:19,931 - DEBUG - File '_4.xlsx' - Row 13: Raw JAN = 2, Raw FEB = 0
# 2025-02-17 13:12:19,933 - DEBUG - File '_6.xlsx' read successfully. Data shape: (7, 5)
# 2025-02-17 13:12:19,934 - DEBUG - File '_5.xlsx' - Row 7: Raw JAN = 17, Raw FEB = 4
# 2025-02-17 13:12:19,935 - INFO - File '_4.xlsx' processed successfully with 10 rows.
# 2025-02-17 13:12:19,937 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,939 - DEBUG - File '_7.xlsx' read successfully. Data shape: (6, 5)
# 2025-02-17 13:12:19,939 - DEBUG - File '_5.xlsx' - Row 8: Raw JAN = 15, Raw FEB = 11
# 2025-02-17 13:12:19,940 - INFO - Processing file: _8.xlsx
# 2025-02-17 13:12:19,941 - INFO - Extracted metadata for '_6.xlsx': RTO='KAMLE - AR23', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,941 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,942 - DEBUG - File '_5.xlsx' - Row 9: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,944 - DEBUG - Header row detected at row 3 in '_6.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,944 - INFO - Extracted metadata for '_7.xlsx': RTO='Keyi Panyor - AR27', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,945 - DEBUG - File '_5.xlsx' - Row 10: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,945 - DEBUG - File '_6.xlsx' - Row 4: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,947 - DEBUG - Header row detected at row 3 in '_7.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,948 - DEBUG - File '_5.xlsx' - Row 11: Raw JAN = 61, Raw FEB = 26
# 2025-02-17 13:12:19,951 - DEBUG - File '_8.xlsx' read successfully. Data shape: (4, 5)
# 2025-02-17 13:12:19,951 - DEBUG - File '_6.xlsx' - Row 5: Raw JAN = 3, Raw FEB = 1
# 2025-02-17 13:12:19,952 - DEBUG - File '_7.xlsx' - Row 4: Raw JAN = 0, Raw FEB = 1
# 2025-02-17 13:12:19,953 - DEBUG - File '_5.xlsx' - Row 12: Raw JAN = 1, Raw FEB = 1
# 2025-02-17 13:12:19,953 - DEBUG - Option 3 metadata extraction succeeded.
# 2025-02-17 13:12:19,954 - DEBUG - File '_6.xlsx' - Row 6: Raw JAN = 1, Raw FEB = 1
# 2025-02-17 13:12:19,955 - DEBUG - File '_7.xlsx' - Row 5: Raw JAN = 3, Raw FEB = 1
# 2025-02-17 13:12:19,956 - DEBUG - File '_5.xlsx' - Row 13: Raw JAN = 396, Raw FEB = 194
# 2025-02-17 13:12:19,957 - INFO - Extracted metadata for '_8.xlsx': RTO='DAADI - AR19', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,958 - INFO - File '_6.xlsx' processed successfully with 3 rows.
# 2025-02-17 13:12:19,958 - INFO - File '_7.xlsx' processed successfully with 2 rows.
# 2025-02-17 13:12:19,959 - DEBUG - File '_5.xlsx' - Row 14: Raw JAN = 8, Raw FEB = 3
# 2025-02-17 13:12:19,960 - DEBUG - Header row detected at row 3 in '_8.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,961 - INFO - Processing file: _9.xlsx
# 2025-02-17 13:12:19,962 - DEBUG - File '_5.xlsx' - Row 15: Raw JAN = 578, Raw FEB = 305
# 2025-02-17 13:12:19,963 - WARNING - No valid data extracted from '_8.xlsx'.
# 2025-02-17 13:12:19,964 - DEBUG - File '_5.xlsx' - Row 16: Raw JAN = 5, Raw FEB = 0
# 2025-02-17 13:12:19,965 - DEBUG - File '_5.xlsx' - Row 17: Raw JAN = 3, Raw FEB = 1
# 2025-02-17 13:12:19,966 - DEBUG - File '_5.xlsx' - Row 18: Raw JAN = 7, Raw FEB = 3
# 2025-02-17 13:12:19,967 - DEBUG - File '_5.xlsx' - Row 19: Raw JAN = 0, Raw FEB = 2
# 2025-02-17 13:12:19,968 - INFO - File '_5.xlsx' processed successfully with 16 rows.
# 2025-02-17 13:12:19,971 - DEBUG - File '_9.xlsx' read successfully. Data shape: (6, 5)
# 2025-02-17 13:12:19,972 - DEBUG - Option 2 metadata extraction succeeded.
# 2025-02-17 13:12:19,972 - INFO - Extracted metadata for '_9.xlsx': RTO='KURUNG KUMEY - AR15', State='Arunachal Pradesh'
# 2025-02-17 13:12:19,973 - DEBUG - Header row detected at row 3 in '_9.xlsx': [nan, nan, 'JAN', 'FEB', nan]
# 2025-02-17 13:12:19,974 - DEBUG - File '_9.xlsx' - Row 4: Raw JAN = 0, Raw FEB = 2
# 2025-02-17 13:12:19,975 - DEBUG - File '_9.xlsx' - Row 5: Raw JAN = 6, Raw FEB = 2
# 2025-02-17 13:12:19,976 - INFO - File '_9.xlsx' processed successfully with 2 rows.
# 2025-02-17 13:12:20,011 - INFO - Combined output successfully saved to 'C:\Users\ASUS\OneDrive\Desktop\Consolidated Maker Wise Data (17-02-2025).xlsx'.
# 2025-02-17 13:12:20,012 - INFO - Processing Summary:
# 2025-02-17 13:12:20,012 - INFO -   Total files processed: 28
# 2025-02-17 13:12:20,013 - INFO -   Successfully processed: 26
# 2025-02-17 13:12:20,013 - INFO -   Files with errors/skipped: 2
# 2025-02-17 13:12:20,013 - INFO -   Total records combined: 150
# 2025-02-17 13:12:20,014 - INFO -   Total processing time: 0.46 seconds
# 2025-02-17 13:12:20,014 - INFO -   Records with non-zero values: 150
# 2025-02-17 13:12:20,015 - INFO -   Top 5 vehicle classes by count:
# 2025-02-17 13:12:20,015 - INFO - Vehicle Class
# M-CYCLE/SCOOTER         26
# MOTOR CAR               26
# GOODS CARRIER           18
# DUMPER                  13
# TRACTOR (COMMERCIAL)    13
# 2025-02-17 13:12:20,016 - INFO -   Records by state:
# 2025-02-17 13:12:20,017 - INFO - State
# Arunachal Pradesh    150
# 2025-02-17 13:12:20,017 - INFO - Vehicle Data Processing completed successfully.
# Processing completed successfully. Check the output folder and log file for details.
